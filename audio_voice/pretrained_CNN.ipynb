# %%
import pandas as pd
import numpy as np
from tensorflow import keras
import matplotlib.pyplot as plt

# %%
from glob import glob
import librosa
import librosa.display

# %%
# 데이터 불러오기 


africa_list = glob("./data/train/africa/*.wav")#glob 함수는 입력하는 폴더 아래 파일들의 path를 가져온다.
australia_list = glob("./data/train/australia/*.wav")#glob 함수는 입력하는 폴더 아래 파일들의 path를 가져온다.
canada_list = glob("./data/train/canada/*.wav")#glob 함수는 입력하는 폴더 아래 파일들의 path를 가져온다.
england_list = glob("./data/train/england/*.wav")#glob 함수는 입력하는 폴더 아래 파일들의 path를 가져온다.
hongkong_list = glob("./data/train/hongkong/*.wav")#glob 함수는 입력하는 폴더 아래 파일들의 path를 가져온다.
us_list = glob("./data/train/us/*.wav")#glob 함수는 입력하는 폴더 아래 파일들의 path를 가져온다.


X_list = africa_list + canada_list + england_list +australia_list +hongkong_list + us_list
Y_list = [0]*len(africa_list)+[1]*len(australia_list) + [2]*len(canada_list)+ [3]*len(england_list)+ [4]*len(hongkong_list)+ [5]*len(us_list)
# 라벨명 :  아프리카: 0 , 호주: 1, 캐나다: 2 , 영국: 3, 홍콩: 4,   미국: 5

# %%
# 오디오 데이터로 만들어 주기.
x_list_audio = [ librosa.load(x)[0] for x in X_list]

# %%
#문제. 각 데이터마다 이미지 사이즈가 다르다.
# 처음부터 읽어올때 시그널 사이즈를 맞춰주자!
# 5초 정도로 자르기. 5초보다 짧은 음성은 0으로 채워주기. padding이라고 부른다.

#패딩 함수
length = 22050*5 # 5초 사이즈 padding을 위한 파라미터 
pad1d = lambda a, i: a[0:i] if a.shape[0] > i else np.hstack((a, np.zeros((i-a.shape[0]))))        
#sig = pad1d(sig,length) 
x_list_audio = [ pad1d(librosa.load(x)[0],length) for x in X_list]

# %%
sr =22050
win_length =  np.int64(sr/40) # 
n_fft= win_length # WINDOWS SIZE중 사용할 길이. WINDOW SIZE가 넘어가면 나머지 것들은 zero padding
hop_length= np.int64( np.ceil(win_length/4) ) #  얼마만큼 시간 주기를 이동하면서 분석을 할 것인지. 일반적으로 window size의 1/4
#또는 10ms만큼으로 한다고 한다. (stride)
#hop: 윈도우가 겹치는 사이즈

# mel spectrogram으로 변환
x_list_audio = [librosa.feature.melspectrogram(y=x, sr=sr,win_length=win_length ,n_fft=n_fft, hop_length=hop_length) for x in x_list_audio ] 
x_list_audio = [librosa.core.power_to_db(x,ref=np.max) for x in x_list_audio ] 


x_list_audio = np.array(x_list_audio) # 리스트를 numpy array로

# %%
print(x_list_audio.shape)
# (batch,컬럼) 형태의 구조
#x_train_audio


#128 *799 사이즈의 1296개 이미지가 생성된다.
# Out:
# (1296, 128, 799)

# %%
#validation set 두기 (정확한 평가를 위해서)
#주로 하이퍼 파라미터 찾기 위해서 validation set을 둔다.

from sklearn.model_selection import train_test_split

x_train,x_validate,y_train,y_validate = train_test_split(x_list_audio,Y_list, test_size = 0.2,random_state = 12345)


#y label들 numpy 바꿔주기 
y_train= np.array(y_train)
y_validate= np.array(y_validate)

print(x_train.shape, x_validate.shape)
# Out:
# (1036, 128, 799) (260, 128, 799)

# %%
# 이미지는 3채널이어야 하기에 rgb 3채널로 복사해주기

x_train = np.repeat(x_train[:, :, :, np.newaxis], 3, axis=3)
x_validate = np.repeat(x_validate[:, :, :, np.newaxis], 3, axis=3)

# %%
print(x_train.shape, x_validate.shape)
# Out:
# (1036, 128, 799, 3) (260, 128, 799, 3)

# %%
#모델 구축
#https://keras.io/api/applications/
from tensorflow.keras import layers
from tensorflow.keras import Model
from tensorflow.keras.applications import ResNet50




res_model = ResNet50(input_shape=(128,799, 3),
                              include_top=False,
                              weights="imagenet")

res_model.summary()
# Out:
# Model: "resnet50"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 128, 799, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 134, 805, 3)  0           ['input_1[0][0]']
#
#  conv1_conv (Conv2D)            (None, 64, 400, 64)  9472        ['conv1_pad[0][0]']
#
#  conv1_bn (BatchNormalization)  (None, 64, 400, 64)  256         ['conv1_conv[0][0]']
#
#  conv1_relu (Activation)        (None, 64, 400, 64)  0           ['conv1_bn[0][0]']
#
#  pool1_pad (ZeroPadding2D)      (None, 66, 402, 64)  0           ['conv1_relu[0][0]']
#
#  pool1_pool (MaxPooling2D)      (None, 32, 200, 64)  0           ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2D)   (None, 32, 200, 64)  4160        ['pool1_pool[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 32, 200, 64)  256        ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 32, 200, 64)  0          ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 32, 200, 64)  36928       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 32, 200, 64)  256        ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 32, 200, 64)  0          ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 32, 200, 256  16640       ['pool1_pool[0][0]']
#                                 )
#
#  conv2_block1_3_conv (Conv2D)   (None, 32, 200, 256  16640       ['conv2_block1_2_relu[0][0]']
#                                 )
#
#  conv2_block1_0_bn (BatchNormal  (None, 32, 200, 256  1024       ['conv2_block1_0_conv[0][0]']
#  ization)                       )
#
#  conv2_block1_3_bn (BatchNormal  (None, 32, 200, 256  1024       ['conv2_block1_3_conv[0][0]']
#  ization)                       )
#
#  conv2_block1_add (Add)         (None, 32, 200, 256  0           ['conv2_block1_0_bn[0][0]',
#                                 )                                 'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activation)  (None, 32, 200, 256  0           ['conv2_block1_add[0][0]']
#                                 )
#
#  conv2_block2_1_conv (Conv2D)   (None, 32, 200, 64)  16448       ['conv2_block1_out[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 32, 200, 64)  256        ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 32, 200, 64)  0          ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 32, 200, 64)  36928       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 32, 200, 64)  256        ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 32, 200, 64)  0          ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 32, 200, 256  16640       ['conv2_block2_2_relu[0][0]']
#                                 )
#
#  conv2_block2_3_bn (BatchNormal  (None, 32, 200, 256  1024       ['conv2_block2_3_conv[0][0]']
#  ization)                       )
#
#  conv2_block2_add (Add)         (None, 32, 200, 256  0           ['conv2_block1_out[0][0]',
#                                 )                                 'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activation)  (None, 32, 200, 256  0           ['conv2_block2_add[0][0]']
#                                 )
#
#  conv2_block3_1_conv (Conv2D)   (None, 32, 200, 64)  16448       ['conv2_block2_out[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 32, 200, 64)  256        ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 32, 200, 64)  0          ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 32, 200, 64)  36928       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 32, 200, 64)  256        ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 32, 200, 64)  0          ['conv2_block3_2_bn[0][0]']
#  n)
#
#  conv2_block3_3_conv (Conv2D)   (None, 32, 200, 256  16640       ['conv2_block3_2_relu[0][0]']
#                                 )
#
#  conv2_block3_3_bn (BatchNormal  (None, 32, 200, 256  1024       ['conv2_block3_3_conv[0][0]']
#  ization)                       )
#
#  conv2_block3_add (Add)         (None, 32, 200, 256  0           ['conv2_block2_out[0][0]',
#                                 )                                 'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activation)  (None, 32, 200, 256  0           ['conv2_block3_add[0][0]']
#                                 )
#
#  conv3_block1_1_conv (Conv2D)   (None, 16, 100, 128  32896       ['conv2_block3_out[0][0]']
#                                 )
#
#  conv3_block1_1_bn (BatchNormal  (None, 16, 100, 128  512        ['conv3_block1_1_conv[0][0]']
#  ization)                       )
#
#  conv3_block1_1_relu (Activatio  (None, 16, 100, 128  0          ['conv3_block1_1_bn[0][0]']
#  n)                             )
#
#  conv3_block1_2_conv (Conv2D)   (None, 16, 100, 128  147584      ['conv3_block1_1_relu[0][0]']
#                                 )
#
#  conv3_block1_2_bn (BatchNormal  (None, 16, 100, 128  512        ['conv3_block1_2_conv[0][0]']
#  ization)                       )
#
#  conv3_block1_2_relu (Activatio  (None, 16, 100, 128  0          ['conv3_block1_2_bn[0][0]']
#  n)                             )
#
#  conv3_block1_0_conv (Conv2D)   (None, 16, 100, 512  131584      ['conv2_block3_out[0][0]']
#                                 )
#
#  conv3_block1_3_conv (Conv2D)   (None, 16, 100, 512  66048       ['conv3_block1_2_relu[0][0]']
#                                 )
#
#  conv3_block1_0_bn (BatchNormal  (None, 16, 100, 512  2048       ['conv3_block1_0_conv[0][0]']
#  ization)                       )
#
#  conv3_block1_3_bn (BatchNormal  (None, 16, 100, 512  2048       ['conv3_block1_3_conv[0][0]']
#  ization)                       )
#
#  conv3_block1_add (Add)         (None, 16, 100, 512  0           ['conv3_block1_0_bn[0][0]',
#                                 )                                 'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activation)  (None, 16, 100, 512  0           ['conv3_block1_add[0][0]']
#                                 )
#
#  conv3_block2_1_conv (Conv2D)   (None, 16, 100, 128  65664       ['conv3_block1_out[0][0]']
#                                 )
#
#  conv3_block2_1_bn (BatchNormal  (None, 16, 100, 128  512        ['conv3_block2_1_conv[0][0]']
#  ization)                       )
#
#  conv3_block2_1_relu (Activatio  (None, 16, 100, 128  0          ['conv3_block2_1_bn[0][0]']
#  n)                             )
#
#  conv3_block2_2_conv (Conv2D)   (None, 16, 100, 128  147584      ['conv3_block2_1_relu[0][0]']
#                                 )
#
#  conv3_block2_2_bn (BatchNormal  (None, 16, 100, 128  512        ['conv3_block2_2_conv[0][0]']
#  ization)                       )
#
#  conv3_block2_2_relu (Activatio  (None, 16, 100, 128  0          ['conv3_block2_2_bn[0][0]']
#  n)                             )
#
#  conv3_block2_3_conv (Conv2D)   (None, 16, 100, 512  66048       ['conv3_block2_2_relu[0][0]']
#                                 )
#
#  conv3_block2_3_bn (BatchNormal  (None, 16, 100, 512  2048       ['conv3_block2_3_conv[0][0]']
#  ization)                       )
#
#  conv3_block2_add (Add)         (None, 16, 100, 512  0           ['conv3_block1_out[0][0]',
#                                 )                                 'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activation)  (None, 16, 100, 512  0           ['conv3_block2_add[0][0]']
#                                 )
#
#  conv3_block3_1_conv (Conv2D)   (None, 16, 100, 128  65664       ['conv3_block2_out[0][0]']
#                                 )
#
#  conv3_block3_1_bn (BatchNormal  (None, 16, 100, 128  512        ['conv3_block3_1_conv[0][0]']
#  ization)                       )
#
#  conv3_block3_1_relu (Activatio  (None, 16, 100, 128  0          ['conv3_block3_1_bn[0][0]']
#  n)                             )
#
#  conv3_block3_2_conv (Conv2D)   (None, 16, 100, 128  147584      ['conv3_block3_1_relu[0][0]']
#                                 )
#
#  conv3_block3_2_bn (BatchNormal  (None, 16, 100, 128  512        ['conv3_block3_2_conv[0][0]']
#  ization)                       )
#
#  conv3_block3_2_relu (Activatio  (None, 16, 100, 128  0          ['conv3_block3_2_bn[0][0]']
#  n)                             )
#
#  conv3_block3_3_conv (Conv2D)   (None, 16, 100, 512  66048       ['conv3_block3_2_relu[0][0]']
#                                 )
#
#  conv3_block3_3_bn (BatchNormal  (None, 16, 100, 512  2048       ['conv3_block3_3_conv[0][0]']
#  ization)                       )
#
#  conv3_block3_add (Add)         (None, 16, 100, 512  0           ['conv3_block2_out[0][0]',
#                                 )                                 'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activation)  (None, 16, 100, 512  0           ['conv3_block3_add[0][0]']
#                                 )
#
#  conv3_block4_1_conv (Conv2D)   (None, 16, 100, 128  65664       ['conv3_block3_out[0][0]']
#                                 )
#
#  conv3_block4_1_bn (BatchNormal  (None, 16, 100, 128  512        ['conv3_block4_1_conv[0][0]']
#  ization)                       )
#
#  conv3_block4_1_relu (Activatio  (None, 16, 100, 128  0          ['conv3_block4_1_bn[0][0]']
#  n)                             )
#
#  conv3_block4_2_conv (Conv2D)   (None, 16, 100, 128  147584      ['conv3_block4_1_relu[0][0]']
#                                 )
#
#  conv3_block4_2_bn (BatchNormal  (None, 16, 100, 128  512        ['conv3_block4_2_conv[0][0]']
#  ization)                       )
#
#  conv3_block4_2_relu (Activatio  (None, 16, 100, 128  0          ['conv3_block4_2_bn[0][0]']
#  n)                             )
#
#  conv3_block4_3_conv (Conv2D)   (None, 16, 100, 512  66048       ['conv3_block4_2_relu[0][0]']
#                                 )
#
#  conv3_block4_3_bn (BatchNormal  (None, 16, 100, 512  2048       ['conv3_block4_3_conv[0][0]']
#  ization)                       )
#
#  conv3_block4_add (Add)         (None, 16, 100, 512  0           ['conv3_block3_out[0][0]',
#                                 )                                 'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activation)  (None, 16, 100, 512  0           ['conv3_block4_add[0][0]']
#                                 )
#
#  conv4_block1_1_conv (Conv2D)   (None, 8, 50, 256)   131328      ['conv3_block4_out[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 8, 50, 256)  1024        ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 8, 50, 256)  0           ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 8, 50, 256)   590080      ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 8, 50, 256)  1024        ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 8, 50, 256)  0           ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 8, 50, 1024)  525312      ['conv3_block4_out[0][0]']
#
#  conv4_block1_3_conv (Conv2D)   (None, 8, 50, 1024)  263168      ['conv4_block1_2_relu[0][0]']
#
#  conv4_block1_0_bn (BatchNormal  (None, 8, 50, 1024)  4096       ['conv4_block1_0_conv[0][0]']
#  ization)
#
#  conv4_block1_3_bn (BatchNormal  (None, 8, 50, 1024)  4096       ['conv4_block1_3_conv[0][0]']
#  ization)
#
#  conv4_block1_add (Add)         (None, 8, 50, 1024)  0           ['conv4_block1_0_bn[0][0]',
#                                                                   'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activation)  (None, 8, 50, 1024)  0           ['conv4_block1_add[0][0]']
#
#  conv4_block2_1_conv (Conv2D)   (None, 8, 50, 256)   262400      ['conv4_block1_out[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 8, 50, 256)  1024        ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 8, 50, 256)  0           ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 8, 50, 256)   590080      ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 8, 50, 256)  1024        ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 8, 50, 256)  0           ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 8, 50, 1024)  263168      ['conv4_block2_2_relu[0][0]']
#
#  conv4_block2_3_bn (BatchNormal  (None, 8, 50, 1024)  4096       ['conv4_block2_3_conv[0][0]']
#  ization)
#
#  conv4_block2_add (Add)         (None, 8, 50, 1024)  0           ['conv4_block1_out[0][0]',
#                                                                   'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activation)  (None, 8, 50, 1024)  0           ['conv4_block2_add[0][0]']
#
#  conv4_block3_1_conv (Conv2D)   (None, 8, 50, 256)   262400      ['conv4_block2_out[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 8, 50, 256)  1024        ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 8, 50, 256)  0           ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 8, 50, 256)   590080      ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 8, 50, 256)  1024        ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 8, 50, 256)  0           ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 8, 50, 1024)  263168      ['conv4_block3_2_relu[0][0]']
#
#  conv4_block3_3_bn (BatchNormal  (None, 8, 50, 1024)  4096       ['conv4_block3_3_conv[0][0]']
#  ization)
#
#  conv4_block3_add (Add)         (None, 8, 50, 1024)  0           ['conv4_block2_out[0][0]',
#                                                                   'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activation)  (None, 8, 50, 1024)  0           ['conv4_block3_add[0][0]']
#
#  conv4_block4_1_conv (Conv2D)   (None, 8, 50, 256)   262400      ['conv4_block3_out[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 8, 50, 256)  1024        ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 8, 50, 256)  0           ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 8, 50, 256)   590080      ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 8, 50, 256)  1024        ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 8, 50, 256)  0           ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 8, 50, 1024)  263168      ['conv4_block4_2_relu[0][0]']
#
#  conv4_block4_3_bn (BatchNormal  (None, 8, 50, 1024)  4096       ['conv4_block4_3_conv[0][0]']
#  ization)
#
#  conv4_block4_add (Add)         (None, 8, 50, 1024)  0           ['conv4_block3_out[0][0]',
#                                                                   'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activation)  (None, 8, 50, 1024)  0           ['conv4_block4_add[0][0]']
#
#  conv4_block5_1_conv (Conv2D)   (None, 8, 50, 256)   262400      ['conv4_block4_out[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 8, 50, 256)  1024        ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 8, 50, 256)  0           ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 8, 50, 256)   590080      ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 8, 50, 256)  1024        ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 8, 50, 256)  0           ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 8, 50, 1024)  263168      ['conv4_block5_2_relu[0][0]']
#
#  conv4_block5_3_bn (BatchNormal  (None, 8, 50, 1024)  4096       ['conv4_block5_3_conv[0][0]']
#  ization)
#
#  conv4_block5_add (Add)         (None, 8, 50, 1024)  0           ['conv4_block4_out[0][0]',
#                                                                   'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activation)  (None, 8, 50, 1024)  0           ['conv4_block5_add[0][0]']
#
#  conv4_block6_1_conv (Conv2D)   (None, 8, 50, 256)   262400      ['conv4_block5_out[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 8, 50, 256)  1024        ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 8, 50, 256)  0           ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_conv (Conv2D)   (None, 8, 50, 256)   590080      ['conv4_block6_1_relu[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 8, 50, 256)  1024        ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 8, 50, 256)  0           ['conv4_block6_2_bn[0][0]']
#  n)
#
#  conv4_block6_3_conv (Conv2D)   (None, 8, 50, 1024)  263168      ['conv4_block6_2_relu[0][0]']
#
#  conv4_block6_3_bn (BatchNormal  (None, 8, 50, 1024)  4096       ['conv4_block6_3_conv[0][0]']
#  ization)
#
#  conv4_block6_add (Add)         (None, 8, 50, 1024)  0           ['conv4_block5_out[0][0]',
#                                                                   'conv4_block6_3_bn[0][0]']
#
#  conv4_block6_out (Activation)  (None, 8, 50, 1024)  0           ['conv4_block6_add[0][0]']
#
#  conv5_block1_1_conv (Conv2D)   (None, 4, 25, 512)   524800      ['conv4_block6_out[0][0]']
#
#  conv5_block1_1_bn (BatchNormal  (None, 4, 25, 512)  2048        ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 4, 25, 512)  0           ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_conv (Conv2D)   (None, 4, 25, 512)   2359808     ['conv5_block1_1_relu[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 4, 25, 512)  2048        ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 4, 25, 512)  0           ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 4, 25, 2048)  2099200     ['conv4_block6_out[0][0]']
#
#  conv5_block1_3_conv (Conv2D)   (None, 4, 25, 2048)  1050624     ['conv5_block1_2_relu[0][0]']
#
#  conv5_block1_0_bn (BatchNormal  (None, 4, 25, 2048)  8192       ['conv5_block1_0_conv[0][0]']
#  ization)
#
#  conv5_block1_3_bn (BatchNormal  (None, 4, 25, 2048)  8192       ['conv5_block1_3_conv[0][0]']
#  ization)
#
#  conv5_block1_add (Add)         (None, 4, 25, 2048)  0           ['conv5_block1_0_bn[0][0]',
#                                                                   'conv5_block1_3_bn[0][0]']
#
#  conv5_block1_out (Activation)  (None, 4, 25, 2048)  0           ['conv5_block1_add[0][0]']
#
#  conv5_block2_1_conv (Conv2D)   (None, 4, 25, 512)   1049088     ['conv5_block1_out[0][0]']
#
#  conv5_block2_1_bn (BatchNormal  (None, 4, 25, 512)  2048        ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 4, 25, 512)  0           ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_conv (Conv2D)   (None, 4, 25, 512)   2359808     ['conv5_block2_1_relu[0][0]']
#
#  conv5_block2_2_bn (BatchNormal  (None, 4, 25, 512)  2048        ['conv5_block2_2_conv[0][0]']
#  ization)
#
#  conv5_block2_2_relu (Activatio  (None, 4, 25, 512)  0           ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 4, 25, 2048)  1050624     ['conv5_block2_2_relu[0][0]']
#
#  conv5_block2_3_bn (BatchNormal  (None, 4, 25, 2048)  8192       ['conv5_block2_3_conv[0][0]']
#  ization)
#
#  conv5_block2_add (Add)         (None, 4, 25, 2048)  0           ['conv5_block1_out[0][0]',
#                                                                   'conv5_block2_3_bn[0][0]']
#
#  conv5_block2_out (Activation)  (None, 4, 25, 2048)  0           ['conv5_block2_add[0][0]']
#
#  conv5_block3_1_conv (Conv2D)   (None, 4, 25, 512)   1049088     ['conv5_block2_out[0][0]']
#
#  conv5_block3_1_bn (BatchNormal  (None, 4, 25, 512)  2048        ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 4, 25, 512)  0           ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_conv (Conv2D)   (None, 4, 25, 512)   2359808     ['conv5_block3_1_relu[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 4, 25, 512)  2048        ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 4, 25, 512)  0           ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 4, 25, 2048)  1050624     ['conv5_block3_2_relu[0][0]']
#
#  conv5_block3_3_bn (BatchNormal  (None, 4, 25, 2048)  8192       ['conv5_block3_3_conv[0][0]']
#  ization)
#
#  conv5_block3_add (Add)         (None, 4, 25, 2048)  0           ['conv5_block2_out[0][0]',
#                                                                   'conv5_block3_3_bn[0][0]']
#
#  conv5_block3_out (Activation)  (None, 4, 25, 2048)  0           ['conv5_block3_add[0][0]']
#
# ==================================================================================================
# Total params: 23,587,712
# Trainable params: 23,534,592
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %%
import numpy as np
res_model(np.random.randn(1,128,799,3)).shape
# Out:
# TensorShape([1, 4, 25, 2048])

# %%
#모델 구축
from keras.models import Sequential
from keras.layers import Dense,BatchNormalization,Dropout,Activation,Flatten

def resnet50_model():
    pretrained_model = res_model
    model = Sequential()

    # Add the vgg convolutional base model
    model.add(pretrained_model)

    # Add new layers
    model.add(Flatten())
    model.add(Dense(2048, activation='relu'))   
    model.add(Dense(256, activation='relu'))
    model.add(Dense(6, activation='softmax')) # 6개의 국가로 나눠야하기 때문. softmax함수가 7개의 국가일 확률을 구해준다.
    return model

nn_model= resnet50_model()

# %%
#compile이란 우리가 만든 모델을 어떻게 weight들을 최적화 시킬지 정해주는 부분.
from keras.optimizers import Adam
nn_model.compile(loss ='sparse_categorical_crossentropy', optimizer=Adam(learning_rate=0.001),metrics =['accuracy'])
#Adam은 가중치를 학습 시켜주는 optimizer중 가장 유명한 것.
#learning rate는 데이터, 전처리 방법에 따라 달라진다. 스스로 조절해가며 찾아야한다.
#metrics는 학습하면서 평가해주는 중간결과를 보여줄 때 사용.

#sparse_categorical_crossentropy는 0~10으로된 수치형 라벨을 10개로 만들어진 백터와 매칭시켜준다.

#categorical_crossentropy를 쓰면,0~10칸으로 된 라벨을 10개 벡터와 매칭.

# %%
nn_model.fit(
    x_train,
    y_train,
    batch_size=16,
    epochs=10,
    verbose=1,
    validation_data=(x_validate,y_validate),
)
# Out:
# Epoch 1/10
# 65/65 [==============================] - 14s 155ms/step - loss: 12.0955 - accuracy: 0.2780 - val_loss: 4191.4429 - val_accuracy: 0.1808
# Epoch 2/10
# 65/65 [==============================] - 9s 131ms/step - loss: 1.4586 - accuracy: 0.4054 - val_loss: 33.0027 - val_accuracy: 0.1962
# Epoch 3/10
# 65/65 [==============================] - 9s 133ms/step - loss: 1.1586 - accuracy: 0.5685 - val_loss: 17.1967 - val_accuracy: 0.2000
# Epoch 4/10
# 65/65 [==============================] - 9s 132ms/step - loss: 0.9634 - accuracy: 0.6660 - val_loss: 1.6618 - val_accuracy: 0.4462
# Epoch 5/10
# 65/65 [==============================] - 8s 130ms/step - loss: 0.6495 - accuracy: 0.7790 - val_loss: 1.6053 - val_accuracy: 0.4077
# Epoch 6/10
# 65/65 [==============================] - 9s 134ms/step - loss: 0.5830 - accuracy: 0.8050 - val_loss: 1.4957 - val_accuracy: 0.6000
# Epoch 7/10
# 65/65 [==============================] - 9s 132ms/step - loss: 0.4538 - accuracy: 0.8523 - val_loss: 2.3842 - val_accuracy: 0.5654
# Epoch 8/10
# 65/65 [==============================] - 9s 133ms/step - loss: 0.3025 - accuracy: 0.9025 - val_loss: 1.4515 - val_accuracy: 0.5769
# Epoch 9/10
# 65/65 [==============================] - 9s 134ms/step - loss: 0.2167 - accuracy: 0.9286 - val_loss: 3.0118 - val_accuracy: 0.3269
# Epoch 10/10
# 65/65 [==============================] - 9s 131ms/step - loss: 0.2788 - accuracy: 0.9266 - val_loss: 2.5454 - val_accuracy: 0.4731

# %%
#from numba import cuda
#cuda.select_device(0)
#cuda.close()

# %% [markdown]
# # 테스트 코드 작성

# %%
# 테스트 데이터 읽어서 mel spectrogram으로 만들기

test_list = glob("./data/test/*.wav")#glob 함수는 입력하는 폴더 아래 파일들의 path를 가져온다.
#단, test파일이 1~60000으로 정렬 되어있는지 확인하기.

# %%
test_list
# Out:
# ['./data/test\\1.wav',
#  './data/test\\10.wav',
#  './data/test\\100.wav',
#  './data/test\\1000.wav',
#  './data/test\\1001.wav',
#  './data/test\\1002.wav',
#  './data/test\\1003.wav',
#  './data/test\\1004.wav',
#  './data/test\\1005.wav',
#  './data/test\\1006.wav',
#  './data/test\\1007.wav',
#  './data/test\\1008.wav',
#  './data/test\\1009.wav',
#  './data/test\\101.wav',
#  './data/test\\1010.wav',
#  './data/test\\1011.wav',
#  './data/test\\1012.wav',
#  './data/test\\1013.wav',
#  './data/test\\1014.wav',
#  './data/test\\1015.wav',
#  './data/test\\1016.wav',
#  './data/test\\1017.wav',
#  './data/test\\1018.wav',
#  './data/test\\1019.wav',
#  './data/test\\102.wav',
#  './data/test\\1020.wav',
#  './data/test\\1021.wav',
#  './data/test\\1022.wav',
#  './data/test\\1023.wav',
#  './data/test\\1024.wav',
#  './data/test\\1025.wav',
#  './data/test\\1026.wav',
#  './data/test\\1027.wav',
#  './data/test\\1028.wav',
#  './data/test\\1029.wav',
#  './data/test\\103.wav',
#  './data/test\\1030.wav',
#  './data/test\\1031.wav',
#  './data/test\\1032.wav',
#  './data/test\\1033.wav',
#  './data/test\\1034.wav',
#  './data/test\\1035.wav',
#  './data/test\\1036.wav',
#  './data/test\\1037.wav',
#  './data/test\\1038.wav',
#  './data/test\\1039.wav',
#  './data/test\\104.wav',
#  './data/test\\1040.wav',
#  './data/test\\1041.wav',
#  './data/test\\1042.wav',
#  './data/test\\1043.wav',
#  './data/test\\1044.wav',
#  './data/test\\1045.wav',
#  './data/test\\1046.wav',
#  './data/test\\1047.wav',
#  './data/test\\1048.wav',
#  './data/test\\1049.wav',
#  './data/test\\105.wav',
#  './data/test\\1050.wav',
#  './data/test\\1051.wav',
#  './data/test\\1052.wav',
#  './data/test\\1053.wav',
#  './data/test\\1054.wav',
#  './data/test\\1055.wav',
#  './data/test\\1056.wav',
#  './data/test\\1057.wav',
#  './data/test\\1058.wav',
#  './data/test\\1059.wav',
#  './data/test\\106.wav',
#  './data/test\\1060.wav',
#  './data/test\\1061.wav',
#  './data/test\\1062.wav',
#  './data/test\\1063.wav',
#  './data/test\\1064.wav',
#  './data/test\\1065.wav',
#  './data/test\\1066.wav',
#  './data/test\\1067.wav',
#  './data/test\\1068.wav',
#  './data/test\\1069.wav',
#  './data/test\\107.wav',
#  './data/test\\1070.wav',
#  './data/test\\1071.wav',
#  './data/test\\1072.wav',
#  './data/test\\1073.wav',
#  './data/test\\1074.wav',
#  './data/test\\1075.wav',
#  './data/test\\1076.wav',
#  './data/test\\1077.wav',
#  './data/test\\1078.wav',
#  './data/test\\1079.wav',
#  './data/test\\108.wav',
#  './data/test\\1080.wav',
#  './data/test\\1081.wav',
#  './data/test\\1082.wav',
#  './data/test\\1083.wav',
#  './data/test\\1084.wav',
#  './data/test\\1085.wav',
#  './data/test\\1086.wav',
#  './data/test\\1087.wav',
#  './data/test\\1088.wav',
#  './data/test\\1089.wav',
#  './data/test\\109.wav',
#  './data/test\\1090.wav',
#  './data/test\\1091.wav',
#  './data/test\\1092.wav',
#  './data/test\\1093.wav',
#  './data/test\\1094.wav',
#  './data/test\\1095.wav',
#  './data/test\\1096.wav',
#  './data/test\\1097.wav',
#  './data/test\\1098.wav',
#  './data/test\\1099.wav',
#  './data/test\\11.wav',
#  './data/test\\110.wav',
#  './data/test\\1100.wav',
#  './data/test\\1101.wav',
#  './data/test\\1102.wav',
#  './data/test\\1103.wav',
#  './data/test\\1104.wav',
#  './data/test\\1105.wav',
#  './data/test\\1106.wav',
#  './data/test\\1107.wav',
#  './data/test\\1108.wav',
#  './data/test\\1109.wav',
#  './data/test\\111.wav',
#  './data/test\\1110.wav',
#  './data/test\\1111.wav',
#  './data/test\\1112.wav',
#  './data/test\\1113.wav',
#  './data/test\\1114.wav',
#  './data/test\\1115.wav',
#  './data/test\\1116.wav',
#  './data/test\\1117.wav',
#  './data/test\\1118.wav',
#  './data/test\\1119.wav',
#  './data/test\\112.wav',
#  './data/test\\1120.wav',
#  './data/test\\1121.wav',
#  './data/test\\1122.wav',
#  './data/test\\1123.wav',
#  './data/test\\1124.wav',
#  './data/test\\1125.wav',
#  './data/test\\1126.wav',
#  './data/test\\1127.wav',
#  './data/test\\1128.wav',
#  './data/test\\1129.wav',
#  './data/test\\113.wav',
#  './data/test\\1130.wav',
#  './data/test\\1131.wav',
#  './data/test\\1132.wav',
#  './data/test\\1133.wav',
#  './data/test\\1134.wav',
#  './data/test\\1135.wav',
#  './data/test\\1136.wav',
#  './data/test\\1137.wav',
#  './data/test\\1138.wav',
#  './data/test\\1139.wav',
#  './data/test\\114.wav',
#  './data/test\\1140.wav',
#  './data/test\\1141.wav',
#  './data/test\\1142.wav',
#  './data/test\\1143.wav',
#  './data/test\\1144.wav',
#  './data/test\\1145.wav',
#  './data/test\\1146.wav',
#  './data/test\\1147.wav',
#  './data/test\\1148.wav',
#  './data/test\\1149.wav',
#  './data/test\\115.wav',
#  './data/test\\1150.wav',
#  './data/test\\1151.wav',
#  './data/test\\1152.wav',
#  './data/test\\1153.wav',
#  './data/test\\1154.wav',
#  './data/test\\1155.wav',
#  './data/test\\1156.wav',
#  './data/test\\1157.wav',
#  './data/test\\1158.wav',
#  './data/test\\1159.wav',
#  './data/test\\116.wav',
#  './data/test\\1160.wav',
#  './data/test\\1161.wav',
#  './data/test\\1162.wav',
#  './data/test\\1163.wav',
#  './data/test\\1164.wav',
#  './data/test\\1165.wav',
#  './data/test\\1166.wav',
#  './data/test\\1167.wav',
#  './data/test\\1168.wav',
#  './data/test\\1169.wav',
#  './data/test\\117.wav',
#  './data/test\\1170.wav',
#  './data/test\\1171.wav',
#  './data/test\\1172.wav',
#  './data/test\\1173.wav',
#  './data/test\\1174.wav',
#  './data/test\\1175.wav',
#  './data/test\\1176.wav',
#  './data/test\\1177.wav',
#  './data/test\\1178.wav',
#  './data/test\\1179.wav',
#  './data/test\\118.wav',
#  './data/test\\1180.wav',
#  './data/test\\1181.wav',
#  './data/test\\1182.wav',
#  './data/test\\1183.wav',
#  './data/test\\1184.wav',
#  './data/test\\1185.wav',
#  './data/test\\1186.wav',
#  './data/test\\1187.wav',
#  './data/test\\1188.wav',
#  './data/test\\1189.wav',
#  './data/test\\119.wav',
#  './data/test\\1190.wav',
#  './data/test\\1191.wav',
#  './data/test\\1192.wav',
#  './data/test\\1193.wav',
#  './data/test\\1194.wav',
#  './data/test\\1195.wav',
#  './data/test\\1196.wav',
#  './data/test\\1197.wav',
#  './data/test\\1198.wav',
#  './data/test\\1199.wav',
#  './data/test\\12.wav',
#  './data/test\\120.wav',
#  './data/test\\1200.wav',
#  './data/test\\1201.wav',
#  './data/test\\1202.wav',
#  './data/test\\1203.wav',
#  './data/test\\1204.wav',
#  './data/test\\1205.wav',
#  './data/test\\1206.wav',
#  './data/test\\1207.wav',
#  './data/test\\1208.wav',
#  './data/test\\1209.wav',
#  './data/test\\121.wav',
#  './data/test\\1210.wav',
#  './data/test\\1211.wav',
#  './data/test\\1212.wav',
#  './data/test\\1213.wav',
#  './data/test\\1214.wav',
#  './data/test\\1215.wav',
#  './data/test\\1216.wav',
#  './data/test\\1217.wav',
#  './data/test\\1218.wav',
#  './data/test\\1219.wav',
#  './data/test\\122.wav',
#  './data/test\\1220.wav',
#  './data/test\\1221.wav',
#  './data/test\\1222.wav',
#  './data/test\\1223.wav',
#  './data/test\\1224.wav',
#  './data/test\\1225.wav',
#  './data/test\\1226.wav',
#  './data/test\\1227.wav',
#  './data/test\\1228.wav',
#  './data/test\\1229.wav',
#  './data/test\\123.wav',
#  './data/test\\1230.wav',
#  './data/test\\1231.wav',
#  './data/test\\1232.wav',
#  './data/test\\1233.wav',
#  './data/test\\1234.wav',
#  './data/test\\1235.wav',
#  './data/test\\1236.wav',
#  './data/test\\1237.wav',
#  './data/test\\1238.wav',
#  './data/test\\1239.wav',
#  './data/test\\124.wav',
#  './data/test\\1240.wav',
#  './data/test\\1241.wav',
#  './data/test\\1242.wav',
#  './data/test\\1243.wav',
#  './data/test\\1244.wav',
#  './data/test\\1245.wav',
#  './data/test\\1246.wav',
#  './data/test\\1247.wav',
#  './data/test\\1248.wav',
#  './data/test\\1249.wav',
#  './data/test\\125.wav',
#  './data/test\\1250.wav',
#  './data/test\\1251.wav',
#  './data/test\\1252.wav',
#  './data/test\\1253.wav',
#  './data/test\\1254.wav',
#  './data/test\\1255.wav',
#  './data/test\\1256.wav',
#  './data/test\\1257.wav',
#  './data/test\\1258.wav',
#  './data/test\\1259.wav',
#  './data/test\\126.wav',
#  './data/test\\1260.wav',
#  './data/test\\1261.wav',
#  './data/test\\1262.wav',
#  './data/test\\1263.wav',
#  './data/test\\1264.wav',
#  './data/test\\1265.wav',
#  './data/test\\1266.wav',
#  './data/test\\1267.wav',
#  './data/test\\1268.wav',
#  './data/test\\1269.wav',
#  './data/test\\127.wav',
#  './data/test\\1270.wav',
#  './data/test\\1271.wav',
#  './data/test\\1272.wav',
#  './data/test\\1273.wav',
#  './data/test\\1274.wav',
#  './data/test\\1275.wav',
#  './data/test\\1276.wav',
#  './data/test\\1277.wav',
#  './data/test\\1278.wav',
#  './data/test\\1279.wav',
#  './data/test\\128.wav',
#  './data/test\\1280.wav',
#  './data/test\\1281.wav',
#  './data/test\\1282.wav',
#  './data/test\\1283.wav',
#  './data/test\\1284.wav',
#  './data/test\\1285.wav',
#  './data/test\\1286.wav',
#  './data/test\\1287.wav',
#  './data/test\\1288.wav',
#  './data/test\\1289.wav',
#  './data/test\\129.wav',
#  './data/test\\1290.wav',
#  './data/test\\1291.wav',
#  './data/test\\1292.wav',
#  './data/test\\1293.wav',
#  './data/test\\1294.wav',
#  './data/test\\1295.wav',
#  './data/test\\1296.wav',
#  './data/test\\1297.wav',
#  './data/test\\1298.wav',
#  './data/test\\1299.wav',
#  './data/test\\13.wav',
#  './data/test\\130.wav',
#  './data/test\\1300.wav',
#  './data/test\\1301.wav',
#  './data/test\\1302.wav',
#  './data/test\\1303.wav',
#  './data/test\\1304.wav',
#  './data/test\\1305.wav',
#  './data/test\\1306.wav',
#  './data/test\\1307.wav',
#  './data/test\\1308.wav',
#  './data/test\\1309.wav',
#  './data/test\\131.wav',
#  './data/test\\1310.wav',
#  './data/test\\1311.wav',
#  './data/test\\1312.wav',
#  './data/test\\1313.wav',
#  './data/test\\1314.wav',
#  './data/test\\1315.wav',
#  './data/test\\1316.wav',
#  './data/test\\1317.wav',
#  './data/test\\1318.wav',
#  './data/test\\1319.wav',
#  './data/test\\132.wav',
#  './data/test\\1320.wav',
#  './data/test\\1321.wav',
#  './data/test\\1322.wav',
#  './data/test\\1323.wav',
#  './data/test\\1324.wav',
#  './data/test\\1325.wav',
#  './data/test\\1326.wav',
#  './data/test\\1327.wav',
#  './data/test\\1328.wav',
#  './data/test\\1329.wav',
#  './data/test\\133.wav',
#  './data/test\\1330.wav',
#  './data/test\\1331.wav',
#  './data/test\\1332.wav',
#  './data/test\\1333.wav',
#  './data/test\\1334.wav',
#  './data/test\\1335.wav',
#  './data/test\\1336.wav',
#  './data/test\\1337.wav',
#  './data/test\\1338.wav',
#  './data/test\\1339.wav',
#  './data/test\\134.wav',
#  './data/test\\1340.wav',
#  './data/test\\1341.wav',
#  './data/test\\1342.wav',
#  './data/test\\1343.wav',
#  './data/test\\1344.wav',
#  './data/test\\1345.wav',
#  './data/test\\1346.wav',
#  './data/test\\1347.wav',
#  './data/test\\1348.wav',
#  './data/test\\1349.wav',
#  './data/test\\135.wav',
#  './data/test\\1350.wav',
#  './data/test\\1351.wav',
#  './data/test\\1352.wav',
#  './data/test\\1353.wav',
#  './data/test\\1354.wav',
#  './data/test\\1355.wav',
#  './data/test\\1356.wav',
#  './data/test\\1357.wav',
#  './data/test\\1358.wav',
#  './data/test\\1359.wav',
#  './data/test\\136.wav',
#  './data/test\\1360.wav',
#  './data/test\\1361.wav',
#  './data/test\\1362.wav',
#  './data/test\\1363.wav',
#  './data/test\\1364.wav',
#  './data/test\\1365.wav',
#  './data/test\\1366.wav',
#  './data/test\\1367.wav',
#  './data/test\\1368.wav',
#  './data/test\\1369.wav',
#  './data/test\\137.wav',
#  './data/test\\1370.wav',
#  './data/test\\1371.wav',
#  './data/test\\1372.wav',
#  './data/test\\1373.wav',
#  './data/test\\1374.wav',
#  './data/test\\1375.wav',
#  './data/test\\1376.wav',
#  './data/test\\1377.wav',
#  './data/test\\1378.wav',
#  './data/test\\1379.wav',
#  './data/test\\138.wav',
#  './data/test\\1380.wav',
#  './data/test\\1381.wav',
#  './data/test\\1382.wav',
#  './data/test\\1383.wav',
#  './data/test\\1384.wav',
#  './data/test\\1385.wav',
#  './data/test\\1386.wav',
#  './data/test\\1387.wav',
#  './data/test\\1388.wav',
#  './data/test\\1389.wav',
#  './data/test\\139.wav',
#  './data/test\\1390.wav',
#  './data/test\\1391.wav',
#  './data/test\\1392.wav',
#  './data/test\\1393.wav',
#  './data/test\\1394.wav',
#  './data/test\\1395.wav',
#  './data/test\\1396.wav',
#  './data/test\\1397.wav',
#  './data/test\\1398.wav',
#  './data/test\\1399.wav',
#  './data/test\\14.wav',
#  './data/test\\140.wav',
#  './data/test\\1400.wav',
#  './data/test\\1401.wav',
#  './data/test\\1402.wav',
#  './data/test\\1403.wav',
#  './data/test\\1404.wav',
#  './data/test\\1405.wav',
#  './data/test\\1406.wav',
#  './data/test\\1407.wav',
#  './data/test\\1408.wav',
#  './data/test\\1409.wav',
#  './data/test\\141.wav',
#  './data/test\\1410.wav',
#  './data/test\\1411.wav',
#  './data/test\\1412.wav',
#  './data/test\\1413.wav',
#  './data/test\\1414.wav',
#  './data/test\\1415.wav',
#  './data/test\\1416.wav',
#  './data/test\\1417.wav',
#  './data/test\\1418.wav',
#  './data/test\\1419.wav',
#  './data/test\\142.wav',
#  './data/test\\1420.wav',
#  './data/test\\1421.wav',
#  './data/test\\1422.wav',
#  './data/test\\1423.wav',
#  './data/test\\1424.wav',
#  './data/test\\1425.wav',
#  './data/test\\1426.wav',
#  './data/test\\1427.wav',
#  './data/test\\1428.wav',
#  './data/test\\1429.wav',
#  './data/test\\143.wav',
#  './data/test\\1430.wav',
#  './data/test\\1431.wav',
#  './data/test\\1432.wav',
#  './data/test\\1433.wav',
#  './data/test\\1434.wav',
#  './data/test\\1435.wav',
#  './data/test\\1436.wav',
#  './data/test\\1437.wav',
#  './data/test\\1438.wav',
#  './data/test\\1439.wav',
#  './data/test\\144.wav',
#  './data/test\\1440.wav',
#  './data/test\\1441.wav',
#  './data/test\\1442.wav',
#  './data/test\\1443.wav',
#  './data/test\\1444.wav',
#  './data/test\\1445.wav',
#  './data/test\\1446.wav',
#  './data/test\\1447.wav',
#  './data/test\\1448.wav',
#  './data/test\\1449.wav',
#  './data/test\\145.wav',
#  './data/test\\1450.wav',
#  './data/test\\1451.wav',
#  './data/test\\1452.wav',
#  './data/test\\1453.wav',
#  './data/test\\1454.wav',
#  './data/test\\1455.wav',
#  './data/test\\1456.wav',
#  './data/test\\1457.wav',
#  './data/test\\1458.wav',
#  './data/test\\1459.wav',
#  './data/test\\146.wav',
#  './data/test\\1460.wav',
#  './data/test\\1461.wav',
#  './data/test\\1462.wav',
#  './data/test\\1463.wav',
#  './data/test\\1464.wav',
#  './data/test\\1465.wav',
#  './data/test\\1466.wav',
#  './data/test\\1467.wav',
#  './data/test\\1468.wav',
#  './data/test\\1469.wav',
#  './data/test\\147.wav',
#  './data/test\\1470.wav',
#  './data/test\\1471.wav',
#  './data/test\\1472.wav',
#  './data/test\\1473.wav',
#  './data/test\\1474.wav',
#  './data/test\\1475.wav',
#  './data/test\\1476.wav',
#  './data/test\\1477.wav',
#  './data/test\\1478.wav',
#  './data/test\\1479.wav',
#  './data/test\\148.wav',
#  './data/test\\1480.wav',
#  './data/test\\1481.wav',
#  './data/test\\1482.wav',
#  './data/test\\1483.wav',
#  './data/test\\1484.wav',
#  './data/test\\1485.wav',
#  './data/test\\1486.wav',
#  './data/test\\1487.wav',
#  './data/test\\1488.wav',
#  './data/test\\1489.wav',
#  './data/test\\149.wav',
#  './data/test\\1490.wav',
#  './data/test\\1491.wav',
#  './data/test\\1492.wav',
#  './data/test\\1493.wav',
#  './data/test\\1494.wav',
#  './data/test\\1495.wav',
#  './data/test\\1496.wav',
#  './data/test\\1497.wav',
#  './data/test\\1498.wav',
#  './data/test\\1499.wav',
#  './data/test\\15.wav',
#  './data/test\\150.wav',
#  './data/test\\1500.wav',
#  './data/test\\1501.wav',
#  './data/test\\1502.wav',
#  './data/test\\1503.wav',
#  './data/test\\1504.wav',
#  './data/test\\1505.wav',
#  './data/test\\1506.wav',
#  './data/test\\1507.wav',
#  './data/test\\1508.wav',
#  './data/test\\1509.wav',
#  './data/test\\151.wav',
#  './data/test\\1510.wav',
#  './data/test\\1511.wav',
#  './data/test\\1512.wav',
#  './data/test\\1513.wav',
#  './data/test\\1514.wav',
#  './data/test\\1515.wav',
#  './data/test\\1516.wav',
#  './data/test\\1517.wav',
#  './data/test\\1518.wav',
#  './data/test\\1519.wav',
#  './data/test\\152.wav',
#  './data/test\\1520.wav',
#  './data/test\\1521.wav',
#  './data/test\\1522.wav',
#  './data/test\\1523.wav',
#  './data/test\\1524.wav',
#  './data/test\\1525.wav',
#  './data/test\\1526.wav',
#  './data/test\\1527.wav',
#  './data/test\\1528.wav',
#  './data/test\\1529.wav',
#  './data/test\\153.wav',
#  './data/test\\1530.wav',
#  './data/test\\1531.wav',
#  './data/test\\1532.wav',
#  './data/test\\1533.wav',
#  './data/test\\1534.wav',
#  './data/test\\1535.wav',
#  './data/test\\1536.wav',
#  './data/test\\1537.wav',
#  './data/test\\1538.wav',
#  './data/test\\1539.wav',
#  './data/test\\154.wav',
#  './data/test\\1540.wav',
#  './data/test\\1541.wav',
#  './data/test\\1542.wav',
#  './data/test\\1543.wav',
#  './data/test\\1544.wav',
#  './data/test\\1545.wav',
#  './data/test\\1546.wav',
#  './data/test\\1547.wav',
#  './data/test\\1548.wav',
#  './data/test\\1549.wav',
#  './data/test\\155.wav',
#  './data/test\\1550.wav',
#  './data/test\\1551.wav',
#  './data/test\\1552.wav',
#  './data/test\\1553.wav',
#  './data/test\\1554.wav',
#  './data/test\\1555.wav',
#  './data/test\\1556.wav',
#  './data/test\\1557.wav',
#  './data/test\\1558.wav',
#  './data/test\\1559.wav',
#  './data/test\\156.wav',
#  './data/test\\1560.wav',
#  './data/test\\1561.wav',
#  './data/test\\1562.wav',
#  './data/test\\1563.wav',
#  './data/test\\1564.wav',
#  './data/test\\1565.wav',
#  './data/test\\1566.wav',
#  './data/test\\1567.wav',
#  './data/test\\1568.wav',
#  './data/test\\1569.wav',
#  './data/test\\157.wav',
#  './data/test\\1570.wav',
#  './data/test\\1571.wav',
#  './data/test\\1572.wav',
#  './data/test\\1573.wav',
#  './data/test\\1574.wav',
#  './data/test\\1575.wav',
#  './data/test\\1576.wav',
#  './data/test\\1577.wav',
#  './data/test\\1578.wav',
#  './data/test\\1579.wav',
#  './data/test\\158.wav',
#  './data/test\\1580.wav',
#  './data/test\\1581.wav',
#  './data/test\\1582.wav',
#  './data/test\\1583.wav',
#  './data/test\\1584.wav',
#  './data/test\\1585.wav',
#  './data/test\\1586.wav',
#  './data/test\\1587.wav',
#  './data/test\\1588.wav',
#  './data/test\\1589.wav',
#  './data/test\\159.wav',
#  './data/test\\1590.wav',
#  './data/test\\1591.wav',
#  './data/test\\1592.wav',
#  './data/test\\1593.wav',
#  './data/test\\1594.wav',
#  './data/test\\1595.wav',
#  './data/test\\1596.wav',
#  './data/test\\1597.wav',
#  './data/test\\1598.wav',
#  './data/test\\1599.wav',
#  './data/test\\16.wav',
#  './data/test\\160.wav',
#  './data/test\\1600.wav',
#  './data/test\\1601.wav',
#  './data/test\\1602.wav',
#  './data/test\\1603.wav',
#  './data/test\\1604.wav',
#  './data/test\\1605.wav',
#  './data/test\\1606.wav',
#  './data/test\\1607.wav',
#  './data/test\\1608.wav',
#  './data/test\\1609.wav',
#  './data/test\\161.wav',
#  './data/test\\1610.wav',
#  './data/test\\1611.wav',
#  './data/test\\1612.wav',
#  './data/test\\1613.wav',
#  './data/test\\1614.wav',
#  './data/test\\1615.wav',
#  './data/test\\1616.wav',
#  './data/test\\1617.wav',
#  './data/test\\1618.wav',
#  './data/test\\1619.wav',
#  './data/test\\162.wav',
#  './data/test\\1620.wav',
#  './data/test\\1621.wav',
#  './data/test\\1622.wav',
#  './data/test\\1623.wav',
#  './data/test\\1624.wav',
#  './data/test\\1625.wav',
#  './data/test\\1626.wav',
#  './data/test\\1627.wav',
#  './data/test\\1628.wav',
#  './data/test\\1629.wav',
#  './data/test\\163.wav',
#  './data/test\\1630.wav',
#  './data/test\\1631.wav',
#  './data/test\\1632.wav',
#  './data/test\\1633.wav',
#  './data/test\\1634.wav',
#  './data/test\\1635.wav',
#  './data/test\\1636.wav',
#  './data/test\\1637.wav',
#  './data/test\\1638.wav',
#  './data/test\\1639.wav',
#  './data/test\\164.wav',
#  './data/test\\1640.wav',
#  './data/test\\1641.wav',
#  './data/test\\1642.wav',
#  './data/test\\1643.wav',
#  './data/test\\1644.wav',
#  './data/test\\1645.wav',
#  './data/test\\1646.wav',
#  './data/test\\1647.wav',
#  './data/test\\1648.wav',
#  './data/test\\1649.wav',
#  './data/test\\165.wav',
#  './data/test\\1650.wav',
#  './data/test\\1651.wav',
#  './data/test\\1652.wav',
#  './data/test\\1653.wav',
#  './data/test\\1654.wav',
#  './data/test\\1655.wav',
#  './data/test\\1656.wav',
#  './data/test\\1657.wav',
#  './data/test\\1658.wav',
#  './data/test\\1659.wav',
#  './data/test\\166.wav',
#  './data/test\\1660.wav',
#  './data/test\\1661.wav',
#  './data/test\\1662.wav',
#  './data/test\\1663.wav',
#  './data/test\\1664.wav',
#  './data/test\\1665.wav',
#  './data/test\\1666.wav',
#  './data/test\\1667.wav',
#  './data/test\\1668.wav',
#  './data/test\\1669.wav',
#  './data/test\\167.wav',
#  './data/test\\1670.wav',
#  './data/test\\1671.wav',
#  './data/test\\1672.wav',
#  './data/test\\1673.wav',
#  './data/test\\1674.wav',
#  './data/test\\1675.wav',
#  './data/test\\1676.wav',
#  './data/test\\1677.wav',
#  './data/test\\1678.wav',
#  './data/test\\1679.wav',
#  './data/test\\168.wav',
#  './data/test\\1680.wav',
#  './data/test\\1681.wav',
#  './data/test\\1682.wav',
#  './data/test\\1683.wav',
#  './data/test\\1684.wav',
#  './data/test\\1685.wav',
#  './data/test\\1686.wav',
#  './data/test\\1687.wav',
#  './data/test\\1688.wav',
#  './data/test\\1689.wav',
#  './data/test\\169.wav',
#  './data/test\\1690.wav',
#  './data/test\\1691.wav',
#  './data/test\\1692.wav',
#  './data/test\\1693.wav',
#  './data/test\\1694.wav',
#  './data/test\\1695.wav',
#  './data/test\\1696.wav',
#  './data/test\\1697.wav',
#  './data/test\\1698.wav',
#  './data/test\\1699.wav',
#  './data/test\\17.wav',
#  './data/test\\170.wav',
#  './data/test\\1700.wav',
#  './data/test\\1701.wav',
#  './data/test\\1702.wav',
#  './data/test\\1703.wav',
#  './data/test\\1704.wav',
#  './data/test\\1705.wav',
#  './data/test\\1706.wav',
#  './data/test\\1707.wav',
#  './data/test\\1708.wav',
#  './data/test\\1709.wav',
#  './data/test\\171.wav',
#  './data/test\\1710.wav',
#  './data/test\\1711.wav',
#  './data/test\\1712.wav',
#  './data/test\\1713.wav',
#  './data/test\\1714.wav',
#  './data/test\\1715.wav',
#  './data/test\\1716.wav',
#  './data/test\\1717.wav',
#  './data/test\\1718.wav',
#  './data/test\\1719.wav',
#  './data/test\\172.wav',
#  './data/test\\1720.wav',
#  './data/test\\1721.wav',
#  './data/test\\1722.wav',
#  './data/test\\1723.wav',
#  './data/test\\1724.wav',
#  './data/test\\1725.wav',
#  './data/test\\1726.wav',
#  './data/test\\1727.wav',
#  './data/test\\1728.wav',
#  './data/test\\1729.wav',
#  './data/test\\173.wav',
#  './data/test\\1730.wav',
#  './data/test\\1731.wav',
#  './data/test\\1732.wav',
#  './data/test\\1733.wav',
#  './data/test\\1734.wav',
#  './data/test\\1735.wav',
#  './data/test\\1736.wav',
#  './data/test\\1737.wav',
#  './data/test\\1738.wav',
#  './data/test\\1739.wav',
#  './data/test\\174.wav',
#  './data/test\\1740.wav',
#  './data/test\\1741.wav',
#  './data/test\\1742.wav',
#  './data/test\\1743.wav',
#  './data/test\\1744.wav',
#  './data/test\\1745.wav',
#  './data/test\\1746.wav',
#  './data/test\\1747.wav',
#  './data/test\\1748.wav',
#  './data/test\\1749.wav',
#  './data/test\\175.wav',
#  './data/test\\1750.wav',
#  './data/test\\1751.wav',
#  './data/test\\1752.wav',
#  './data/test\\1753.wav',
#  './data/test\\1754.wav',
#  './data/test\\1755.wav',
#  './data/test\\1756.wav',
#  './data/test\\1757.wav',
#  './data/test\\1758.wav',
#  './data/test\\1759.wav',
#  './data/test\\176.wav',
#  './data/test\\1760.wav',
#  './data/test\\1761.wav',
#  './data/test\\1762.wav',
#  './data/test\\1763.wav',
#  './data/test\\1764.wav',
#  './data/test\\1765.wav',
#  './data/test\\1766.wav',
#  './data/test\\1767.wav',
#  './data/test\\1768.wav',
#  './data/test\\1769.wav',
#  './data/test\\177.wav',
#  './data/test\\1770.wav',
#  './data/test\\1771.wav',
#  './data/test\\1772.wav',
#  './data/test\\1773.wav',
#  './data/test\\1774.wav',
#  './data/test\\1775.wav',
#  './data/test\\1776.wav',
#  './data/test\\1777.wav',
#  './data/test\\1778.wav',
#  './data/test\\1779.wav',
#  './data/test\\178.wav',
#  './data/test\\1780.wav',
#  './data/test\\1781.wav',
#  './data/test\\1782.wav',
#  './data/test\\1783.wav',
#  './data/test\\1784.wav',
#  './data/test\\1785.wav',
#  './data/test\\1786.wav',
#  './data/test\\1787.wav',
#  './data/test\\1788.wav',
#  './data/test\\1789.wav',
#  './data/test\\179.wav',
#  './data/test\\1790.wav',
#  './data/test\\1791.wav',
#  './data/test\\1792.wav',
#  './data/test\\1793.wav',
#  './data/test\\1794.wav',
#  './data/test\\1795.wav',
#  './data/test\\1796.wav',
#  './data/test\\1797.wav',
#  './data/test\\1798.wav',
#  './data/test\\1799.wav',
#  './data/test\\18.wav',
#  './data/test\\180.wav',
#  './data/test\\1800.wav',
#  './data/test\\1801.wav',
#  './data/test\\1802.wav',
#  './data/test\\1803.wav',
#  './data/test\\1804.wav',
#  './data/test\\1805.wav',
#  './data/test\\1806.wav',
#  './data/test\\1807.wav',
#  './data/test\\1808.wav',
#  './data/test\\1809.wav',
#  './data/test\\181.wav',
#  './data/test\\1810.wav',
#  './data/test\\1811.wav',
#  './data/test\\1812.wav',
#  './data/test\\1813.wav',
#  './data/test\\1814.wav',
#  './data/test\\1815.wav',
#  './data/test\\1816.wav',
#  './data/test\\1817.wav',
#  './data/test\\1818.wav',
#  './data/test\\1819.wav',
#  './data/test\\182.wav',
#  './data/test\\1820.wav',
#  './data/test\\1821.wav',
#  './data/test\\1822.wav',
#  './data/test\\1823.wav',
#  './data/test\\1824.wav',
#  './data/test\\1825.wav',
#  './data/test\\1826.wav',
#  './data/test\\1827.wav',
#  './data/test\\1828.wav',
#  './data/test\\1829.wav',
#  './data/test\\183.wav',
#  './data/test\\1830.wav',
#  './data/test\\1831.wav',
#  './data/test\\1832.wav',
#  './data/test\\1833.wav',
#  './data/test\\1834.wav',
#  './data/test\\1835.wav',
#  './data/test\\1836.wav',
#  './data/test\\1837.wav',
#  './data/test\\1838.wav',
#  './data/test\\1839.wav',
#  './data/test\\184.wav',
#  './data/test\\1840.wav',
#  './data/test\\1841.wav',
#  './data/test\\1842.wav',
#  './data/test\\1843.wav',
#  './data/test\\1844.wav',
#  './data/test\\1845.wav',
#  './data/test\\1846.wav',
#  './data/test\\1847.wav',
#  './data/test\\1848.wav',
#  './data/test\\1849.wav',
#  './data/test\\185.wav',
#  './data/test\\1850.wav',
#  './data/test\\1851.wav',
#  './data/test\\1852.wav',
#  './data/test\\1853.wav',
#  './data/test\\1854.wav',
#  './data/test\\1855.wav',
#  './data/test\\1856.wav',
#  './data/test\\1857.wav',
#  './data/test\\1858.wav',
#  './data/test\\1859.wav',
#  './data/test\\186.wav',
#  './data/test\\1860.wav',
#  './data/test\\1861.wav',
#  './data/test\\1862.wav',
#  './data/test\\1863.wav',
#  './data/test\\1864.wav',
#  './data/test\\1865.wav',
#  './data/test\\1866.wav',
#  './data/test\\1867.wav',
#  './data/test\\1868.wav',
#  './data/test\\1869.wav',
#  './data/test\\187.wav',
#  './data/test\\1870.wav',
#  './data/test\\1871.wav',
#  './data/test\\1872.wav',
#  './data/test\\1873.wav',
#  './data/test\\1874.wav',
#  './data/test\\1875.wav',
#  './data/test\\1876.wav',
#  './data/test\\1877.wav',
#  './data/test\\1878.wav',
#  './data/test\\1879.wav',
#  './data/test\\188.wav',
#  './data/test\\1880.wav',
#  './data/test\\1881.wav',
#  './data/test\\1882.wav',
#  './data/test\\1883.wav',
#  './data/test\\1884.wav',
#  './data/test\\1885.wav',
#  './data/test\\1886.wav',
#  './data/test\\1887.wav',
#  './data/test\\1888.wav',
#  './data/test\\1889.wav',
#  './data/test\\189.wav',
#  './data/test\\1890.wav',
#  './data/test\\1891.wav',
#  './data/test\\1892.wav',
#  './data/test\\1893.wav',
#  './data/test\\1894.wav',
#  './data/test\\1895.wav',
#  './data/test\\1896.wav',
#  './data/test\\1897.wav',
#  './data/test\\1898.wav',
#  './data/test\\1899.wav',
#  ...]

# %%
test_list = sorted(test_list,key=lambda x: int(x.split('\\')[1].split('.')[0]))
test_list
# Out:
# ['./data/test\\1.wav',
#  './data/test\\2.wav',
#  './data/test\\3.wav',
#  './data/test\\4.wav',
#  './data/test\\5.wav',
#  './data/test\\6.wav',
#  './data/test\\7.wav',
#  './data/test\\8.wav',
#  './data/test\\9.wav',
#  './data/test\\10.wav',
#  './data/test\\11.wav',
#  './data/test\\12.wav',
#  './data/test\\13.wav',
#  './data/test\\14.wav',
#  './data/test\\15.wav',
#  './data/test\\16.wav',
#  './data/test\\17.wav',
#  './data/test\\18.wav',
#  './data/test\\19.wav',
#  './data/test\\20.wav',
#  './data/test\\21.wav',
#  './data/test\\22.wav',
#  './data/test\\23.wav',
#  './data/test\\24.wav',
#  './data/test\\25.wav',
#  './data/test\\26.wav',
#  './data/test\\27.wav',
#  './data/test\\28.wav',
#  './data/test\\29.wav',
#  './data/test\\30.wav',
#  './data/test\\31.wav',
#  './data/test\\32.wav',
#  './data/test\\33.wav',
#  './data/test\\34.wav',
#  './data/test\\35.wav',
#  './data/test\\36.wav',
#  './data/test\\37.wav',
#  './data/test\\38.wav',
#  './data/test\\39.wav',
#  './data/test\\40.wav',
#  './data/test\\41.wav',
#  './data/test\\42.wav',
#  './data/test\\43.wav',
#  './data/test\\44.wav',
#  './data/test\\45.wav',
#  './data/test\\46.wav',
#  './data/test\\47.wav',
#  './data/test\\48.wav',
#  './data/test\\49.wav',
#  './data/test\\50.wav',
#  './data/test\\51.wav',
#  './data/test\\52.wav',
#  './data/test\\53.wav',
#  './data/test\\54.wav',
#  './data/test\\55.wav',
#  './data/test\\56.wav',
#  './data/test\\57.wav',
#  './data/test\\58.wav',
#  './data/test\\59.wav',
#  './data/test\\60.wav',
#  './data/test\\61.wav',
#  './data/test\\62.wav',
#  './data/test\\63.wav',
#  './data/test\\64.wav',
#  './data/test\\65.wav',
#  './data/test\\66.wav',
#  './data/test\\67.wav',
#  './data/test\\68.wav',
#  './data/test\\69.wav',
#  './data/test\\70.wav',
#  './data/test\\71.wav',
#  './data/test\\72.wav',
#  './data/test\\73.wav',
#  './data/test\\74.wav',
#  './data/test\\75.wav',
#  './data/test\\76.wav',
#  './data/test\\77.wav',
#  './data/test\\78.wav',
#  './data/test\\79.wav',
#  './data/test\\80.wav',
#  './data/test\\81.wav',
#  './data/test\\82.wav',
#  './data/test\\83.wav',
#  './data/test\\84.wav',
#  './data/test\\85.wav',
#  './data/test\\86.wav',
#  './data/test\\87.wav',
#  './data/test\\88.wav',
#  './data/test\\89.wav',
#  './data/test\\90.wav',
#  './data/test\\91.wav',
#  './data/test\\92.wav',
#  './data/test\\93.wav',
#  './data/test\\94.wav',
#  './data/test\\95.wav',
#  './data/test\\96.wav',
#  './data/test\\97.wav',
#  './data/test\\98.wav',
#  './data/test\\99.wav',
#  './data/test\\100.wav',
#  './data/test\\101.wav',
#  './data/test\\102.wav',
#  './data/test\\103.wav',
#  './data/test\\104.wav',
#  './data/test\\105.wav',
#  './data/test\\106.wav',
#  './data/test\\107.wav',
#  './data/test\\108.wav',
#  './data/test\\109.wav',
#  './data/test\\110.wav',
#  './data/test\\111.wav',
#  './data/test\\112.wav',
#  './data/test\\113.wav',
#  './data/test\\114.wav',
#  './data/test\\115.wav',
#  './data/test\\116.wav',
#  './data/test\\117.wav',
#  './data/test\\118.wav',
#  './data/test\\119.wav',
#  './data/test\\120.wav',
#  './data/test\\121.wav',
#  './data/test\\122.wav',
#  './data/test\\123.wav',
#  './data/test\\124.wav',
#  './data/test\\125.wav',
#  './data/test\\126.wav',
#  './data/test\\127.wav',
#  './data/test\\128.wav',
#  './data/test\\129.wav',
#  './data/test\\130.wav',
#  './data/test\\131.wav',
#  './data/test\\132.wav',
#  './data/test\\133.wav',
#  './data/test\\134.wav',
#  './data/test\\135.wav',
#  './data/test\\136.wav',
#  './data/test\\137.wav',
#  './data/test\\138.wav',
#  './data/test\\139.wav',
#  './data/test\\140.wav',
#  './data/test\\141.wav',
#  './data/test\\142.wav',
#  './data/test\\143.wav',
#  './data/test\\144.wav',
#  './data/test\\145.wav',
#  './data/test\\146.wav',
#  './data/test\\147.wav',
#  './data/test\\148.wav',
#  './data/test\\149.wav',
#  './data/test\\150.wav',
#  './data/test\\151.wav',
#  './data/test\\152.wav',
#  './data/test\\153.wav',
#  './data/test\\154.wav',
#  './data/test\\155.wav',
#  './data/test\\156.wav',
#  './data/test\\157.wav',
#  './data/test\\158.wav',
#  './data/test\\159.wav',
#  './data/test\\160.wav',
#  './data/test\\161.wav',
#  './data/test\\162.wav',
#  './data/test\\163.wav',
#  './data/test\\164.wav',
#  './data/test\\165.wav',
#  './data/test\\166.wav',
#  './data/test\\167.wav',
#  './data/test\\168.wav',
#  './data/test\\169.wav',
#  './data/test\\170.wav',
#  './data/test\\171.wav',
#  './data/test\\172.wav',
#  './data/test\\173.wav',
#  './data/test\\174.wav',
#  './data/test\\175.wav',
#  './data/test\\176.wav',
#  './data/test\\177.wav',
#  './data/test\\178.wav',
#  './data/test\\179.wav',
#  './data/test\\180.wav',
#  './data/test\\181.wav',
#  './data/test\\182.wav',
#  './data/test\\183.wav',
#  './data/test\\184.wav',
#  './data/test\\185.wav',
#  './data/test\\186.wav',
#  './data/test\\187.wav',
#  './data/test\\188.wav',
#  './data/test\\189.wav',
#  './data/test\\190.wav',
#  './data/test\\191.wav',
#  './data/test\\192.wav',
#  './data/test\\193.wav',
#  './data/test\\194.wav',
#  './data/test\\195.wav',
#  './data/test\\196.wav',
#  './data/test\\197.wav',
#  './data/test\\198.wav',
#  './data/test\\199.wav',
#  './data/test\\200.wav',
#  './data/test\\201.wav',
#  './data/test\\202.wav',
#  './data/test\\203.wav',
#  './data/test\\204.wav',
#  './data/test\\205.wav',
#  './data/test\\206.wav',
#  './data/test\\207.wav',
#  './data/test\\208.wav',
#  './data/test\\209.wav',
#  './data/test\\210.wav',
#  './data/test\\211.wav',
#  './data/test\\212.wav',
#  './data/test\\213.wav',
#  './data/test\\214.wav',
#  './data/test\\215.wav',
#  './data/test\\216.wav',
#  './data/test\\217.wav',
#  './data/test\\218.wav',
#  './data/test\\219.wav',
#  './data/test\\220.wav',
#  './data/test\\221.wav',
#  './data/test\\222.wav',
#  './data/test\\223.wav',
#  './data/test\\224.wav',
#  './data/test\\225.wav',
#  './data/test\\226.wav',
#  './data/test\\227.wav',
#  './data/test\\228.wav',
#  './data/test\\229.wav',
#  './data/test\\230.wav',
#  './data/test\\231.wav',
#  './data/test\\232.wav',
#  './data/test\\233.wav',
#  './data/test\\234.wav',
#  './data/test\\235.wav',
#  './data/test\\236.wav',
#  './data/test\\237.wav',
#  './data/test\\238.wav',
#  './data/test\\239.wav',
#  './data/test\\240.wav',
#  './data/test\\241.wav',
#  './data/test\\242.wav',
#  './data/test\\243.wav',
#  './data/test\\244.wav',
#  './data/test\\245.wav',
#  './data/test\\246.wav',
#  './data/test\\247.wav',
#  './data/test\\248.wav',
#  './data/test\\249.wav',
#  './data/test\\250.wav',
#  './data/test\\251.wav',
#  './data/test\\252.wav',
#  './data/test\\253.wav',
#  './data/test\\254.wav',
#  './data/test\\255.wav',
#  './data/test\\256.wav',
#  './data/test\\257.wav',
#  './data/test\\258.wav',
#  './data/test\\259.wav',
#  './data/test\\260.wav',
#  './data/test\\261.wav',
#  './data/test\\262.wav',
#  './data/test\\263.wav',
#  './data/test\\264.wav',
#  './data/test\\265.wav',
#  './data/test\\266.wav',
#  './data/test\\267.wav',
#  './data/test\\268.wav',
#  './data/test\\269.wav',
#  './data/test\\270.wav',
#  './data/test\\271.wav',
#  './data/test\\272.wav',
#  './data/test\\273.wav',
#  './data/test\\274.wav',
#  './data/test\\275.wav',
#  './data/test\\276.wav',
#  './data/test\\277.wav',
#  './data/test\\278.wav',
#  './data/test\\279.wav',
#  './data/test\\280.wav',
#  './data/test\\281.wav',
#  './data/test\\282.wav',
#  './data/test\\283.wav',
#  './data/test\\284.wav',
#  './data/test\\285.wav',
#  './data/test\\286.wav',
#  './data/test\\287.wav',
#  './data/test\\288.wav',
#  './data/test\\289.wav',
#  './data/test\\290.wav',
#  './data/test\\291.wav',
#  './data/test\\292.wav',
#  './data/test\\293.wav',
#  './data/test\\294.wav',
#  './data/test\\295.wav',
#  './data/test\\296.wav',
#  './data/test\\297.wav',
#  './data/test\\298.wav',
#  './data/test\\299.wav',
#  './data/test\\300.wav',
#  './data/test\\301.wav',
#  './data/test\\302.wav',
#  './data/test\\303.wav',
#  './data/test\\304.wav',
#  './data/test\\305.wav',
#  './data/test\\306.wav',
#  './data/test\\307.wav',
#  './data/test\\308.wav',
#  './data/test\\309.wav',
#  './data/test\\310.wav',
#  './data/test\\311.wav',
#  './data/test\\312.wav',
#  './data/test\\313.wav',
#  './data/test\\314.wav',
#  './data/test\\315.wav',
#  './data/test\\316.wav',
#  './data/test\\317.wav',
#  './data/test\\318.wav',
#  './data/test\\319.wav',
#  './data/test\\320.wav',
#  './data/test\\321.wav',
#  './data/test\\322.wav',
#  './data/test\\323.wav',
#  './data/test\\324.wav',
#  './data/test\\325.wav',
#  './data/test\\326.wav',
#  './data/test\\327.wav',
#  './data/test\\328.wav',
#  './data/test\\329.wav',
#  './data/test\\330.wav',
#  './data/test\\331.wav',
#  './data/test\\332.wav',
#  './data/test\\333.wav',
#  './data/test\\334.wav',
#  './data/test\\335.wav',
#  './data/test\\336.wav',
#  './data/test\\337.wav',
#  './data/test\\338.wav',
#  './data/test\\339.wav',
#  './data/test\\340.wav',
#  './data/test\\341.wav',
#  './data/test\\342.wav',
#  './data/test\\343.wav',
#  './data/test\\344.wav',
#  './data/test\\345.wav',
#  './data/test\\346.wav',
#  './data/test\\347.wav',
#  './data/test\\348.wav',
#  './data/test\\349.wav',
#  './data/test\\350.wav',
#  './data/test\\351.wav',
#  './data/test\\352.wav',
#  './data/test\\353.wav',
#  './data/test\\354.wav',
#  './data/test\\355.wav',
#  './data/test\\356.wav',
#  './data/test\\357.wav',
#  './data/test\\358.wav',
#  './data/test\\359.wav',
#  './data/test\\360.wav',
#  './data/test\\361.wav',
#  './data/test\\362.wav',
#  './data/test\\363.wav',
#  './data/test\\364.wav',
#  './data/test\\365.wav',
#  './data/test\\366.wav',
#  './data/test\\367.wav',
#  './data/test\\368.wav',
#  './data/test\\369.wav',
#  './data/test\\370.wav',
#  './data/test\\371.wav',
#  './data/test\\372.wav',
#  './data/test\\373.wav',
#  './data/test\\374.wav',
#  './data/test\\375.wav',
#  './data/test\\376.wav',
#  './data/test\\377.wav',
#  './data/test\\378.wav',
#  './data/test\\379.wav',
#  './data/test\\380.wav',
#  './data/test\\381.wav',
#  './data/test\\382.wav',
#  './data/test\\383.wav',
#  './data/test\\384.wav',
#  './data/test\\385.wav',
#  './data/test\\386.wav',
#  './data/test\\387.wav',
#  './data/test\\388.wav',
#  './data/test\\389.wav',
#  './data/test\\390.wav',
#  './data/test\\391.wav',
#  './data/test\\392.wav',
#  './data/test\\393.wav',
#  './data/test\\394.wav',
#  './data/test\\395.wav',
#  './data/test\\396.wav',
#  './data/test\\397.wav',
#  './data/test\\398.wav',
#  './data/test\\399.wav',
#  './data/test\\400.wav',
#  './data/test\\401.wav',
#  './data/test\\402.wav',
#  './data/test\\403.wav',
#  './data/test\\404.wav',
#  './data/test\\405.wav',
#  './data/test\\406.wav',
#  './data/test\\407.wav',
#  './data/test\\408.wav',
#  './data/test\\409.wav',
#  './data/test\\410.wav',
#  './data/test\\411.wav',
#  './data/test\\412.wav',
#  './data/test\\413.wav',
#  './data/test\\414.wav',
#  './data/test\\415.wav',
#  './data/test\\416.wav',
#  './data/test\\417.wav',
#  './data/test\\418.wav',
#  './data/test\\419.wav',
#  './data/test\\420.wav',
#  './data/test\\421.wav',
#  './data/test\\422.wav',
#  './data/test\\423.wav',
#  './data/test\\424.wav',
#  './data/test\\425.wav',
#  './data/test\\426.wav',
#  './data/test\\427.wav',
#  './data/test\\428.wav',
#  './data/test\\429.wav',
#  './data/test\\430.wav',
#  './data/test\\431.wav',
#  './data/test\\432.wav',
#  './data/test\\433.wav',
#  './data/test\\434.wav',
#  './data/test\\435.wav',
#  './data/test\\436.wav',
#  './data/test\\437.wav',
#  './data/test\\438.wav',
#  './data/test\\439.wav',
#  './data/test\\440.wav',
#  './data/test\\441.wav',
#  './data/test\\442.wav',
#  './data/test\\443.wav',
#  './data/test\\444.wav',
#  './data/test\\445.wav',
#  './data/test\\446.wav',
#  './data/test\\447.wav',
#  './data/test\\448.wav',
#  './data/test\\449.wav',
#  './data/test\\450.wav',
#  './data/test\\451.wav',
#  './data/test\\452.wav',
#  './data/test\\453.wav',
#  './data/test\\454.wav',
#  './data/test\\455.wav',
#  './data/test\\456.wav',
#  './data/test\\457.wav',
#  './data/test\\458.wav',
#  './data/test\\459.wav',
#  './data/test\\460.wav',
#  './data/test\\461.wav',
#  './data/test\\462.wav',
#  './data/test\\463.wav',
#  './data/test\\464.wav',
#  './data/test\\465.wav',
#  './data/test\\466.wav',
#  './data/test\\467.wav',
#  './data/test\\468.wav',
#  './data/test\\469.wav',
#  './data/test\\470.wav',
#  './data/test\\471.wav',
#  './data/test\\472.wav',
#  './data/test\\473.wav',
#  './data/test\\474.wav',
#  './data/test\\475.wav',
#  './data/test\\476.wav',
#  './data/test\\477.wav',
#  './data/test\\478.wav',
#  './data/test\\479.wav',
#  './data/test\\480.wav',
#  './data/test\\481.wav',
#  './data/test\\482.wav',
#  './data/test\\483.wav',
#  './data/test\\484.wav',
#  './data/test\\485.wav',
#  './data/test\\486.wav',
#  './data/test\\487.wav',
#  './data/test\\488.wav',
#  './data/test\\489.wav',
#  './data/test\\490.wav',
#  './data/test\\491.wav',
#  './data/test\\492.wav',
#  './data/test\\493.wav',
#  './data/test\\494.wav',
#  './data/test\\495.wav',
#  './data/test\\496.wav',
#  './data/test\\497.wav',
#  './data/test\\498.wav',
#  './data/test\\499.wav',
#  './data/test\\500.wav',
#  './data/test\\501.wav',
#  './data/test\\502.wav',
#  './data/test\\503.wav',
#  './data/test\\504.wav',
#  './data/test\\505.wav',
#  './data/test\\506.wav',
#  './data/test\\507.wav',
#  './data/test\\508.wav',
#  './data/test\\509.wav',
#  './data/test\\510.wav',
#  './data/test\\511.wav',
#  './data/test\\512.wav',
#  './data/test\\513.wav',
#  './data/test\\514.wav',
#  './data/test\\515.wav',
#  './data/test\\516.wav',
#  './data/test\\517.wav',
#  './data/test\\518.wav',
#  './data/test\\519.wav',
#  './data/test\\520.wav',
#  './data/test\\521.wav',
#  './data/test\\522.wav',
#  './data/test\\523.wav',
#  './data/test\\524.wav',
#  './data/test\\525.wav',
#  './data/test\\526.wav',
#  './data/test\\527.wav',
#  './data/test\\528.wav',
#  './data/test\\529.wav',
#  './data/test\\530.wav',
#  './data/test\\531.wav',
#  './data/test\\532.wav',
#  './data/test\\533.wav',
#  './data/test\\534.wav',
#  './data/test\\535.wav',
#  './data/test\\536.wav',
#  './data/test\\537.wav',
#  './data/test\\538.wav',
#  './data/test\\539.wav',
#  './data/test\\540.wav',
#  './data/test\\541.wav',
#  './data/test\\542.wav',
#  './data/test\\543.wav',
#  './data/test\\544.wav',
#  './data/test\\545.wav',
#  './data/test\\546.wav',
#  './data/test\\547.wav',
#  './data/test\\548.wav',
#  './data/test\\549.wav',
#  './data/test\\550.wav',
#  './data/test\\551.wav',
#  './data/test\\552.wav',
#  './data/test\\553.wav',
#  './data/test\\554.wav',
#  './data/test\\555.wav',
#  './data/test\\556.wav',
#  './data/test\\557.wav',
#  './data/test\\558.wav',
#  './data/test\\559.wav',
#  './data/test\\560.wav',
#  './data/test\\561.wav',
#  './data/test\\562.wav',
#  './data/test\\563.wav',
#  './data/test\\564.wav',
#  './data/test\\565.wav',
#  './data/test\\566.wav',
#  './data/test\\567.wav',
#  './data/test\\568.wav',
#  './data/test\\569.wav',
#  './data/test\\570.wav',
#  './data/test\\571.wav',
#  './data/test\\572.wav',
#  './data/test\\573.wav',
#  './data/test\\574.wav',
#  './data/test\\575.wav',
#  './data/test\\576.wav',
#  './data/test\\577.wav',
#  './data/test\\578.wav',
#  './data/test\\579.wav',
#  './data/test\\580.wav',
#  './data/test\\581.wav',
#  './data/test\\582.wav',
#  './data/test\\583.wav',
#  './data/test\\584.wav',
#  './data/test\\585.wav',
#  './data/test\\586.wav',
#  './data/test\\587.wav',
#  './data/test\\588.wav',
#  './data/test\\589.wav',
#  './data/test\\590.wav',
#  './data/test\\591.wav',
#  './data/test\\592.wav',
#  './data/test\\593.wav',
#  './data/test\\594.wav',
#  './data/test\\595.wav',
#  './data/test\\596.wav',
#  './data/test\\597.wav',
#  './data/test\\598.wav',
#  './data/test\\599.wav',
#  './data/test\\600.wav',
#  './data/test\\601.wav',
#  './data/test\\602.wav',
#  './data/test\\603.wav',
#  './data/test\\604.wav',
#  './data/test\\605.wav',
#  './data/test\\606.wav',
#  './data/test\\607.wav',
#  './data/test\\608.wav',
#  './data/test\\609.wav',
#  './data/test\\610.wav',
#  './data/test\\611.wav',
#  './data/test\\612.wav',
#  './data/test\\613.wav',
#  './data/test\\614.wav',
#  './data/test\\615.wav',
#  './data/test\\616.wav',
#  './data/test\\617.wav',
#  './data/test\\618.wav',
#  './data/test\\619.wav',
#  './data/test\\620.wav',
#  './data/test\\621.wav',
#  './data/test\\622.wav',
#  './data/test\\623.wav',
#  './data/test\\624.wav',
#  './data/test\\625.wav',
#  './data/test\\626.wav',
#  './data/test\\627.wav',
#  './data/test\\628.wav',
#  './data/test\\629.wav',
#  './data/test\\630.wav',
#  './data/test\\631.wav',
#  './data/test\\632.wav',
#  './data/test\\633.wav',
#  './data/test\\634.wav',
#  './data/test\\635.wav',
#  './data/test\\636.wav',
#  './data/test\\637.wav',
#  './data/test\\638.wav',
#  './data/test\\639.wav',
#  './data/test\\640.wav',
#  './data/test\\641.wav',
#  './data/test\\642.wav',
#  './data/test\\643.wav',
#  './data/test\\644.wav',
#  './data/test\\645.wav',
#  './data/test\\646.wav',
#  './data/test\\647.wav',
#  './data/test\\648.wav',
#  './data/test\\649.wav',
#  './data/test\\650.wav',
#  './data/test\\651.wav',
#  './data/test\\652.wav',
#  './data/test\\653.wav',
#  './data/test\\654.wav',
#  './data/test\\655.wav',
#  './data/test\\656.wav',
#  './data/test\\657.wav',
#  './data/test\\658.wav',
#  './data/test\\659.wav',
#  './data/test\\660.wav',
#  './data/test\\661.wav',
#  './data/test\\662.wav',
#  './data/test\\663.wav',
#  './data/test\\664.wav',
#  './data/test\\665.wav',
#  './data/test\\666.wav',
#  './data/test\\667.wav',
#  './data/test\\668.wav',
#  './data/test\\669.wav',
#  './data/test\\670.wav',
#  './data/test\\671.wav',
#  './data/test\\672.wav',
#  './data/test\\673.wav',
#  './data/test\\674.wav',
#  './data/test\\675.wav',
#  './data/test\\676.wav',
#  './data/test\\677.wav',
#  './data/test\\678.wav',
#  './data/test\\679.wav',
#  './data/test\\680.wav',
#  './data/test\\681.wav',
#  './data/test\\682.wav',
#  './data/test\\683.wav',
#  './data/test\\684.wav',
#  './data/test\\685.wav',
#  './data/test\\686.wav',
#  './data/test\\687.wav',
#  './data/test\\688.wav',
#  './data/test\\689.wav',
#  './data/test\\690.wav',
#  './data/test\\691.wav',
#  './data/test\\692.wav',
#  './data/test\\693.wav',
#  './data/test\\694.wav',
#  './data/test\\695.wav',
#  './data/test\\696.wav',
#  './data/test\\697.wav',
#  './data/test\\698.wav',
#  './data/test\\699.wav',
#  './data/test\\700.wav',
#  './data/test\\701.wav',
#  './data/test\\702.wav',
#  './data/test\\703.wav',
#  './data/test\\704.wav',
#  './data/test\\705.wav',
#  './data/test\\706.wav',
#  './data/test\\707.wav',
#  './data/test\\708.wav',
#  './data/test\\709.wav',
#  './data/test\\710.wav',
#  './data/test\\711.wav',
#  './data/test\\712.wav',
#  './data/test\\713.wav',
#  './data/test\\714.wav',
#  './data/test\\715.wav',
#  './data/test\\716.wav',
#  './data/test\\717.wav',
#  './data/test\\718.wav',
#  './data/test\\719.wav',
#  './data/test\\720.wav',
#  './data/test\\721.wav',
#  './data/test\\722.wav',
#  './data/test\\723.wav',
#  './data/test\\724.wav',
#  './data/test\\725.wav',
#  './data/test\\726.wav',
#  './data/test\\727.wav',
#  './data/test\\728.wav',
#  './data/test\\729.wav',
#  './data/test\\730.wav',
#  './data/test\\731.wav',
#  './data/test\\732.wav',
#  './data/test\\733.wav',
#  './data/test\\734.wav',
#  './data/test\\735.wav',
#  './data/test\\736.wav',
#  './data/test\\737.wav',
#  './data/test\\738.wav',
#  './data/test\\739.wav',
#  './data/test\\740.wav',
#  './data/test\\741.wav',
#  './data/test\\742.wav',
#  './data/test\\743.wav',
#  './data/test\\744.wav',
#  './data/test\\745.wav',
#  './data/test\\746.wav',
#  './data/test\\747.wav',
#  './data/test\\748.wav',
#  './data/test\\749.wav',
#  './data/test\\750.wav',
#  './data/test\\751.wav',
#  './data/test\\752.wav',
#  './data/test\\753.wav',
#  './data/test\\754.wav',
#  './data/test\\755.wav',
#  './data/test\\756.wav',
#  './data/test\\757.wav',
#  './data/test\\758.wav',
#  './data/test\\759.wav',
#  './data/test\\760.wav',
#  './data/test\\761.wav',
#  './data/test\\762.wav',
#  './data/test\\763.wav',
#  './data/test\\764.wav',
#  './data/test\\765.wav',
#  './data/test\\766.wav',
#  './data/test\\767.wav',
#  './data/test\\768.wav',
#  './data/test\\769.wav',
#  './data/test\\770.wav',
#  './data/test\\771.wav',
#  './data/test\\772.wav',
#  './data/test\\773.wav',
#  './data/test\\774.wav',
#  './data/test\\775.wav',
#  './data/test\\776.wav',
#  './data/test\\777.wav',
#  './data/test\\778.wav',
#  './data/test\\779.wav',
#  './data/test\\780.wav',
#  './data/test\\781.wav',
#  './data/test\\782.wav',
#  './data/test\\783.wav',
#  './data/test\\784.wav',
#  './data/test\\785.wav',
#  './data/test\\786.wav',
#  './data/test\\787.wav',
#  './data/test\\788.wav',
#  './data/test\\789.wav',
#  './data/test\\790.wav',
#  './data/test\\791.wav',
#  './data/test\\792.wav',
#  './data/test\\793.wav',
#  './data/test\\794.wav',
#  './data/test\\795.wav',
#  './data/test\\796.wav',
#  './data/test\\797.wav',
#  './data/test\\798.wav',
#  './data/test\\799.wav',
#  './data/test\\800.wav',
#  './data/test\\801.wav',
#  './data/test\\802.wav',
#  './data/test\\803.wav',
#  './data/test\\804.wav',
#  './data/test\\805.wav',
#  './data/test\\806.wav',
#  './data/test\\807.wav',
#  './data/test\\808.wav',
#  './data/test\\809.wav',
#  './data/test\\810.wav',
#  './data/test\\811.wav',
#  './data/test\\812.wav',
#  './data/test\\813.wav',
#  './data/test\\814.wav',
#  './data/test\\815.wav',
#  './data/test\\816.wav',
#  './data/test\\817.wav',
#  './data/test\\818.wav',
#  './data/test\\819.wav',
#  './data/test\\820.wav',
#  './data/test\\821.wav',
#  './data/test\\822.wav',
#  './data/test\\823.wav',
#  './data/test\\824.wav',
#  './data/test\\825.wav',
#  './data/test\\826.wav',
#  './data/test\\827.wav',
#  './data/test\\828.wav',
#  './data/test\\829.wav',
#  './data/test\\830.wav',
#  './data/test\\831.wav',
#  './data/test\\832.wav',
#  './data/test\\833.wav',
#  './data/test\\834.wav',
#  './data/test\\835.wav',
#  './data/test\\836.wav',
#  './data/test\\837.wav',
#  './data/test\\838.wav',
#  './data/test\\839.wav',
#  './data/test\\840.wav',
#  './data/test\\841.wav',
#  './data/test\\842.wav',
#  './data/test\\843.wav',
#  './data/test\\844.wav',
#  './data/test\\845.wav',
#  './data/test\\846.wav',
#  './data/test\\847.wav',
#  './data/test\\848.wav',
#  './data/test\\849.wav',
#  './data/test\\850.wav',
#  './data/test\\851.wav',
#  './data/test\\852.wav',
#  './data/test\\853.wav',
#  './data/test\\854.wav',
#  './data/test\\855.wav',
#  './data/test\\856.wav',
#  './data/test\\857.wav',
#  './data/test\\858.wav',
#  './data/test\\859.wav',
#  './data/test\\860.wav',
#  './data/test\\861.wav',
#  './data/test\\862.wav',
#  './data/test\\863.wav',
#  './data/test\\864.wav',
#  './data/test\\865.wav',
#  './data/test\\866.wav',
#  './data/test\\867.wav',
#  './data/test\\868.wav',
#  './data/test\\869.wav',
#  './data/test\\870.wav',
#  './data/test\\871.wav',
#  './data/test\\872.wav',
#  './data/test\\873.wav',
#  './data/test\\874.wav',
#  './data/test\\875.wav',
#  './data/test\\876.wav',
#  './data/test\\877.wav',
#  './data/test\\878.wav',
#  './data/test\\879.wav',
#  './data/test\\880.wav',
#  './data/test\\881.wav',
#  './data/test\\882.wav',
#  './data/test\\883.wav',
#  './data/test\\884.wav',
#  './data/test\\885.wav',
#  './data/test\\886.wav',
#  './data/test\\887.wav',
#  './data/test\\888.wav',
#  './data/test\\889.wav',
#  './data/test\\890.wav',
#  './data/test\\891.wav',
#  './data/test\\892.wav',
#  './data/test\\893.wav',
#  './data/test\\894.wav',
#  './data/test\\895.wav',
#  './data/test\\896.wav',
#  './data/test\\897.wav',
#  './data/test\\898.wav',
#  './data/test\\899.wav',
#  './data/test\\900.wav',
#  './data/test\\901.wav',
#  './data/test\\902.wav',
#  './data/test\\903.wav',
#  './data/test\\904.wav',
#  './data/test\\905.wav',
#  './data/test\\906.wav',
#  './data/test\\907.wav',
#  './data/test\\908.wav',
#  './data/test\\909.wav',
#  './data/test\\910.wav',
#  './data/test\\911.wav',
#  './data/test\\912.wav',
#  './data/test\\913.wav',
#  './data/test\\914.wav',
#  './data/test\\915.wav',
#  './data/test\\916.wav',
#  './data/test\\917.wav',
#  './data/test\\918.wav',
#  './data/test\\919.wav',
#  './data/test\\920.wav',
#  './data/test\\921.wav',
#  './data/test\\922.wav',
#  './data/test\\923.wav',
#  './data/test\\924.wav',
#  './data/test\\925.wav',
#  './data/test\\926.wav',
#  './data/test\\927.wav',
#  './data/test\\928.wav',
#  './data/test\\929.wav',
#  './data/test\\930.wav',
#  './data/test\\931.wav',
#  './data/test\\932.wav',
#  './data/test\\933.wav',
#  './data/test\\934.wav',
#  './data/test\\935.wav',
#  './data/test\\936.wav',
#  './data/test\\937.wav',
#  './data/test\\938.wav',
#  './data/test\\939.wav',
#  './data/test\\940.wav',
#  './data/test\\941.wav',
#  './data/test\\942.wav',
#  './data/test\\943.wav',
#  './data/test\\944.wav',
#  './data/test\\945.wav',
#  './data/test\\946.wav',
#  './data/test\\947.wav',
#  './data/test\\948.wav',
#  './data/test\\949.wav',
#  './data/test\\950.wav',
#  './data/test\\951.wav',
#  './data/test\\952.wav',
#  './data/test\\953.wav',
#  './data/test\\954.wav',
#  './data/test\\955.wav',
#  './data/test\\956.wav',
#  './data/test\\957.wav',
#  './data/test\\958.wav',
#  './data/test\\959.wav',
#  './data/test\\960.wav',
#  './data/test\\961.wav',
#  './data/test\\962.wav',
#  './data/test\\963.wav',
#  './data/test\\964.wav',
#  './data/test\\965.wav',
#  './data/test\\966.wav',
#  './data/test\\967.wav',
#  './data/test\\968.wav',
#  './data/test\\969.wav',
#  './data/test\\970.wav',
#  './data/test\\971.wav',
#  './data/test\\972.wav',
#  './data/test\\973.wav',
#  './data/test\\974.wav',
#  './data/test\\975.wav',
#  './data/test\\976.wav',
#  './data/test\\977.wav',
#  './data/test\\978.wav',
#  './data/test\\979.wav',
#  './data/test\\980.wav',
#  './data/test\\981.wav',
#  './data/test\\982.wav',
#  './data/test\\983.wav',
#  './data/test\\984.wav',
#  './data/test\\985.wav',
#  './data/test\\986.wav',
#  './data/test\\987.wav',
#  './data/test\\988.wav',
#  './data/test\\989.wav',
#  './data/test\\990.wav',
#  './data/test\\991.wav',
#  './data/test\\992.wav',
#  './data/test\\993.wav',
#  './data/test\\994.wav',
#  './data/test\\995.wav',
#  './data/test\\996.wav',
#  './data/test\\997.wav',
#  './data/test\\998.wav',
#  './data/test\\999.wav',
#  './data/test\\1000.wav',
#  ...]

# %%
#문제. 각 데이터마다 이미지 사이즈가 다르다.
# 처음부터 읽어올때 시그널 사이즈를 맞춰주자!
# 5초 정도로 자르기. 5초보다 짧은 음성은 0으로 채워주기. padding이라고 부른다.

#패딩 함수
length = 22050*5 # 5초 사이즈 padding을 위한 파라미터 
pad1d = lambda a, i: a[0:i] if a.shape[0] > i else np.hstack((a, np.zeros((i-a.shape[0]))))        
#sig = pad1d(sig,length) 
x_test_audio = [ pad1d(librosa.load(x)[0],length) for x in test_list]

# %%
sr =22050
win_length =  np.int64(sr/40) # 
n_fft= win_length # WINDOWS SIZE중 사용할 길이. WINDOW SIZE가 넘어가면 나머지 것들은 zero padding
hop_length= np.int64( np.ceil(win_length/4) ) #  얼마만큼 시간 주기를 이동하면서 분석을 할 것인지. 일반적으로 window size의 1/4
#또는 10ms만큼으로 한다고 한다. (stride)
#hop: 윈도우가 겹치는 사이즈

# mel spectrogram으로 변환
x_test_audio = [librosa.feature.melspectrogram(y=x, sr=sr,win_length=win_length ,n_fft=n_fft, hop_length=hop_length) for x in x_test_audio ] 
x_test_audio = [librosa.core.power_to_db(x,ref=np.max) for x in x_test_audio ] 


x_test_audio = np.array(x_test_audio) # 리스트를 numpy array로

# %%
# 이미지는 3채널이어야 하기에 rgb 3채널로 복사해주기

x_test_audio = np.repeat(x_test_audio[:, :, :, np.newaxis], 3, axis=3)

# %%
x_test_audio.shape
# Out:
# array([[[[-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ],
#          ...,
#          [-55.97033 , -55.97033 , -55.97033 ],
#          [-60.96189 , -60.96189 , -60.96189 ],
#          [-55.961475, -55.961475, -55.961475]],
#
#         [[-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ],
#          ...,
#          [-55.072906, -55.072906, -55.072906],
#          [-60.064472, -60.064472, -60.064472],
#          [-55.064056, -55.064056, -55.064056]],
#
#         [[-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ],
#          ...,
#          [-45.722275, -45.722275, -45.722275],
#          [-43.806168, -43.806168, -43.806168],
#          [-44.035736, -44.035736, -44.035736]],
#
#         ...,
#
#         [[-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ],
#          ...,
#          [-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ],
#          [-71.89775 , -71.89775 , -71.89775 ]],
#
#         [[-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ],
#          ...,
#          [-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ],
#          [-71.92938 , -71.92938 , -71.92938 ]],
#
#         [[-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ],
#          ...,
#          [-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ],
#          [-71.95595 , -71.95595 , -71.95595 ]]],
#
#
#        [[[-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ],
#          ...,
#          [-40.07348 , -40.07348 , -40.07348 ],
#          [-40.893143, -40.893143, -40.893143],
#          [-42.500874, -42.500874, -42.500874]],
#
#         [[-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ],
#          ...,
#          [-39.17606 , -39.17606 , -39.17606 ],
#          [-39.995724, -39.995724, -39.995724],
#          [-41.603455, -41.603455, -41.603455]],
#
#         [[-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ],
#          ...,
#          [-36.166332, -36.166332, -36.166332],
#          [-42.34539 , -42.34539 , -42.34539 ],
#          [-42.86828 , -42.86828 , -42.86828 ]],
#
#         ...,
#
#         [[-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ],
#          ...,
#          [-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ]],
#
#         [[-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ],
#          ...,
#          [-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ]],
#
#         [[-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ],
#          ...,
#          [-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ]]],
#
#
#        [[[-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ],
#          ...,
#          [-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ]],
#
#         [[-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ],
#          ...,
#          [-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ]],
#
#         [[-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ],
#          ...,
#          [-79.59756 , -79.59756 , -79.59756 ],
#          [-78.23302 , -78.23302 , -78.23302 ],
#          [-79.51957 , -79.51957 , -79.51957 ]],
#
#         ...,
#
#         [[-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ],
#          ...,
#          [-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ]],
#
#         [[-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ],
#          ...,
#          [-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ]],
#
#         [[-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ],
#          ...,
#          [-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ]]],
#
#
#        ...,
#
#
#        [[[-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ],
#          ...,
#          [-80.      , -80.      , -80.      ],
#          [-76.41932 , -76.41932 , -76.41932 ],
#          [-66.04931 , -66.04931 , -66.04931 ]],
#
#         [[-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ],
#          ...,
#          [-80.      , -80.      , -80.      ],
#          [-75.5219  , -75.5219  , -75.5219  ],
#          [-65.151886, -65.151886, -65.151886]],
#
#         [[-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ],
#          ...,
#          [-80.      , -80.      , -80.      ],
#          [-78.74957 , -78.74957 , -78.74957 ],
#          [-59.816303, -59.816303, -59.816303]],
#
#         ...,
#
#         [[-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ],
#          ...,
#          [-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ]],
#
#         [[-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ],
#          ...,
#          [-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ]],
#
#         [[-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ],
#          ...,
#          [-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ]]],
#
#
#        [[[-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ],
#          ...,
#          [-56.652504, -56.652504, -56.652504],
#          [-66.28166 , -66.28166 , -66.28166 ],
#          [-60.827858, -60.827858, -60.827858]],
#
#         [[-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ],
#          ...,
#          [-55.75508 , -55.75508 , -55.75508 ],
#          [-65.38425 , -65.38425 , -65.38425 ],
#          [-59.930443, -59.930443, -59.930443]],
#
#         [[-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ],
#          ...,
#          [-50.55237 , -50.55237 , -50.55237 ],
#          [-50.052773, -50.052773, -50.052773],
#          [-44.435776, -44.435776, -44.435776]],
#
#         ...,
#
#         [[-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ],
#          ...,
#          [-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ]],
#
#         [[-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ],
#          ...,
#          [-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ]],
#
#         [[-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ],
#          ...,
#          [-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ]]],
#
#
#        [[[-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ],
#          ...,
#          [-63.05789 , -63.05789 , -63.05789 ],
#          [-41.325153, -41.325153, -41.325153],
#          [-40.436405, -40.436405, -40.436405]],
#
#         [[-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ],
#          ...,
#          [-62.16047 , -62.16047 , -62.16047 ],
#          [-40.427734, -40.427734, -40.427734],
#          [-39.538986, -39.538986, -39.538986]],
#
#         [[-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ],
#          ...,
#          [-22.841433, -22.841433, -22.841433],
#          [-21.628693, -21.628693, -21.628693],
#          [-21.253155, -21.253155, -21.253155]],
#
#         ...,
#
#         [[-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ],
#          ...,
#          [-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ],
#          [-70.19951 , -70.19951 , -70.19951 ]],
#
#         [[-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ],
#          ...,
#          [-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ],
#          [-70.24779 , -70.24779 , -70.24779 ]],
#
#         [[-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ],
#          ...,
#          [-80.      , -80.      , -80.      ],
#          [-80.      , -80.      , -80.      ],
#          [-70.234375, -70.234375, -70.234375]]]], dtype=float32)

# %%
#메모리가 부족한 상황 때문에 2000개씩 나눠서 투입

y_pred1 = nn_model.predict(x_test_audio[:2000])
# Out:
# 63/63 [==============================] - 4s 51ms/step

# %%
#메모리가 부족한 상황 때문에 2000개씩 나눠서 투입
y_pred2 = nn_model.predict(x_test_audio[2000:2000*2])
# Out:
# 63/63 [==============================] - 3s 52ms/step

# %%
#메모리가 부족한 상황 때문에 2000개씩 나눠서 투입
y_pred3 = nn_model.predict(x_test_audio[2000*2:])
# Out:
# 66/66 [==============================] - 3s 52ms/step

# %%
y_pred1.shape
#6칸에 대해, 확률들을 적어 둔 것.
# Out:
# (2000, 6)

# %%
y_pred1
# Out:
# array([[9.91447091e-01, 1.28490792e-03, 3.23151681e-03, 3.11536784e-03,
#         4.10836568e-04, 5.10178739e-04],
#        [4.48507664e-04, 1.36206208e-05, 2.91154091e-03, 4.57768887e-03,
#         9.92015839e-01, 3.27787857e-05],
#        [5.07604778e-01, 1.96584240e-02, 2.06180792e-02, 6.83906907e-03,
#         1.96295534e-03, 4.43316668e-01],
#        ...,
#        [9.59108353e-01, 2.73326300e-02, 2.00661318e-03, 1.10856621e-02,
#         1.13823946e-04, 3.52977222e-04],
#        [9.92315036e-05, 9.99047458e-01, 4.39733703e-04, 2.75556580e-04,
#         1.19682569e-04, 1.84080818e-05],
#        [9.89243627e-01, 2.32167047e-04, 7.47034675e-04, 9.73202102e-03,
#         9.77367472e-06, 3.53258183e-05]], dtype=float32)

# %%
submission = pd.read_csv('./data/sample_submission.csv', encoding = 'utf-8')

# %%
# 2000번까지 확률 입력
submission.iloc[:2000,1:] = y_pred1 # 예측 확률들을 다 집어넣는다.

# %%
# 2000~4000 확률 입력
submission.iloc[2000:2000*2,1:] = y_pred2 # 예측 확률들을 다 집어넣는다.

# %%
#4000 ~ 그외
submission.iloc[2000*2:,1:] = y_pred3 # 예측 확률들을 다 집어넣는다.

# %%
submission.to_csv('voice_submission.csv', index = False)

# %%
submission.shape
# Out:
# (6100, 7)

# %%
submission
# Out:
#         id    africa     australia    canada   england      hongkong  \
# 0        1  0.991447  1.284908e-03  0.003232  0.003115  4.108366e-04
# 1        2  0.000449  1.362062e-05  0.002912  0.004578  9.920158e-01
# 2        3  0.507605  1.965842e-02  0.020618  0.006839  1.962955e-03
# 3        4  0.999892  2.412206e-07  0.000096  0.000012  7.832716e-09
# 4        5  0.278975  4.281072e-05  0.002175  0.000209  7.105247e-01
# ...    ...       ...           ...       ...       ...           ...
# 6095  6096  0.004261  7.725934e-03  0.870812  0.005711  1.091760e-01
# 6096  6097  0.145086  7.477363e-02  0.754185  0.002669  1.519360e-02
# 6097  6098  0.526848  2.395072e-02  0.098310  0.012020  3.508757e-03
# 6098  6099  0.878183  5.144886e-03  0.019222  0.001225  9.569270e-02
# 6099  6100  0.869784  2.091699e-02  0.099655  0.005180  2.589614e-03
#
#                 us
# 0     5.101787e-04
# 1     3.277879e-05
# 2     4.433167e-01
# 3     5.284309e-08
# 4     8.073536e-03
# ...            ...
# 6095  2.313862e-03
# 6096  8.093343e-03
# 6097  3.353619e-01
# 6098  5.336105e-04
# 6099  1.874558e-03
#
# [6100 rows x 7 columns]

# %% [markdown]
# 점수를 높일 수 있는 시도들
# 1. 데이터셋을 모두 넣는다.
# 2. dacon baseline을 따라 작성해본다
# 3. 다른 코드들 따라한다.
